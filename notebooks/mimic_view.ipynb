# %%
import pandas as pd
import nltk
from tqdm import tqdm
from nltk import word_tokenize
nltk.download('punkt')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2 import nltk
#       3 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'pandas'

# %%
tqdm.pandas()
# Define a custom aggregation function to return a list of unique values
def custom_agg(x):
    return list(x.unique())

# %%
# it contains all the icd9-10 codes and relative only long title
d_icd_diagnoses = pd.read_csv("data/physionet.org/files/mimiciv/2.2/hosp/d_icd_diagnoses.csv.gz", compression="gzip")
#print(d_icd_diagnoses[d_icd_diagnoses.icd_version==10])

# %%
d_icd_diagnoses[d_icd_diagnoses.icd_version==10]
# Out:
#        icd_code  icd_version  \
# 12238       A00           10
# 12239      A000           10
# 12240      A001           10
# 12241      A009           10
# 12242       A01           10
# ...         ...          ...
# 109770     Z992           10
# 109771     Z993           10
# 109772     Z998           10
# 109773    Z9981           10
# 109774    Z9989           10
#
#                                                long_title
# 12238                                             Cholera
# 12239   Cholera due to Vibrio cholerae 01, biovar chol...
# 12240     Cholera due to Vibrio cholerae 01, biovar eltor
# 12241                                Cholera, unspecified
# 12242                      Typhoid and paratyphoid fevers
# ...                                                   ...
# 109770                       Dependence on renal dialysis
# 109771                           Dependence on wheelchair
# 109772  Dependence on other enabling machines and devices
# ...

# %%
len(set(d_icd_diagnoses[d_icd_diagnoses.icd_version==10].icd_code))
# Out:
# 95109

# %%
# this can be joined with the previous one by field (icd_code + icd_version)
diagnoses_icd = pd.read_csv("data/physionet.org/files/mimiciv/2.2/hosp/diagnoses_icd.csv.gz", compression="gzip")
diagnoses_icd.head()
# Out:
#    subject_id   hadm_id  seq_num icd_code  icd_version
# 0    10000032  22595853        1     5723            9
# 1    10000032  22595853        2    78959            9
# 2    10000032  22595853        3     5715            9
# 3    10000032  22595853        4    07070            9
# 4    10000032  22595853        5      496            9

# %%
diagnoses_icd_joined = diagnoses_icd.merge(d_icd_diagnoses, on=["icd_code", "icd_version"])
diagnoses_icd_joined
# Out:
#          subject_id   hadm_id  seq_num icd_code  icd_version  \
# 0          10000032  22595853        1     5723            9
# 1          10000826  20032235        4     5723            9
# 2          10000826  28289260        1     5723            9
# 3          10005866  26158160        4     5723            9
# 4          10008924  23676183        7     5723            9
# ...             ...       ...      ...      ...          ...
# 4756321    19990427  29695607       24  T24011A           10
# 4756322    19996016  28015466        4   O30093           10
# 4756323    19996783  25894657       20  H353131           10
# 4756324    19997062  20096107        1    K8036           10
# 4756325    19999043  23037011       10  O359XX2           10
#
#                                                 long_title
# 0                                      Portal hypertension
# 1                                      Portal hypertension
# ...

# %%
discharge = pd.read_csv("data/physionet.org/files/mimic-iv-note/2.2/note/discharge.csv.gz", compression='gzip', encoding='utf-8')
discharge
# Out:
#                note_id  subject_id   hadm_id note_type  note_seq  \
# 0       10000032-DS-21    10000032  22595853        DS        21
# 1       10000032-DS-22    10000032  22841357        DS        22
# 2       10000032-DS-23    10000032  29079034        DS        23
# 3       10000032-DS-24    10000032  25742920        DS        24
# 4       10000084-DS-17    10000084  23052089        DS        17
# ...                ...         ...       ...       ...       ...
# 331788   19999828-DS-6    19999828  29734428        DS         6
# 331789   19999828-DS-7    19999828  25744818        DS         7
# 331790  19999840-DS-20    19999840  26071774        DS        20
# 331791  19999840-DS-21    19999840  21033226        DS        21
# 331792   19999987-DS-2    19999987  23865745        DS         2
#
#                   charttime            storetime  \
# 0       2180-05-07 00:00:00  2180-05-09 15:26:00
# 1       2180-06-27 00:00:00  2180-07-01 10:15:00
# ...

# %%
df = discharge.merge(diagnoses_icd_joined, on=['subject_id', 'hadm_id'])
df.drop(columns=['note_type', 'note_seq','charttime', 'storetime', 'seq_num'], inplace=True)
print("Dataset read.\n")
# 'note_id', 'subject_id', 'hadm_id', 'icd_code', 'icd_version', 'long_title'
df_icd9 = df[df.icd_version == 9].reset_index(drop=True)
df_icd10 = df[df.icd_version == 10].reset_index(drop=True)
df_icd10.head()
# Out:
# Dataset read.
#           note_id  subject_id   hadm_id  \
# 0  10000084-DS-17    10000084  23052089
# 1  10000084-DS-17    10000084  23052089
# 2  10000084-DS-17    10000084  23052089
# 3  10000084-DS-17    10000084  23052089
# 4  10000084-DS-17    10000084  23052089
#
#                                                 text icd_code  icd_version  \
# 0   \nName:  ___                    Unit No:   __...    G3183           10
# 1   \nName:  ___                    Unit No:   __...    F0280           10
# 2   \nName:  ___                    Unit No:   __...     R441           10
# 3   \nName:  ___                    Unit No:   __...     R296           10
# 4   \nName:  ___                    Unit No:   __...     E785           10
#
#                                           long_title
# 0                          Dementia with Lewy bodies
# 1  Dementia in other diseases classified elsewher...
# 2                              Visual hallucinations
# ...

# %%
df_icd9_grouped = df_icd9.groupby(['note_id', 'subject_id', 'hadm_id', 'icd_version', 'text'])
df_icd9 = df_icd9_grouped.agg({'text': 'first', 'icd_code': custom_agg, 'long_title': custom_agg}).reset_index(drop=True)
df_icd9
# Out:
#                                                      text  \
# 0        \nName:  ___                     Unit No:   _...
# 1        \nName:  ___                     Unit No:   _...
# 2        \nName:  ___                     Unit No:   _...
# 3        \nName:  ___                     Unit No:   _...
# 4        \nName:  ___                      Unit No:   ...
# ...                                                   ...
# 209347   \nName:  ___              Unit No:   ___\n \n...
# 209348   \nName:  ___              Unit No:   ___\n \n...
# 209349   \nName:  ___                  Unit No:   ___\...
# 209350   \nName:  ___                  Unit No:   ___\...
# 209351   \nName:  ___                    Unit No:   __...
#
#                                                  icd_code  \
# 0       [5723, 78959, 5715, 07070, 496, 29680, 30981, ...
# 1        [78959, 5715, 496, 07071, 2875, 2761, V08, 3051]
# 2       [78959, 5715, 496, 29680, 2761, V08, 3051, V46...
# ...

# %%
df_icd10_grouped = df_icd10.groupby(['note_id', 'subject_id', 'hadm_id', 'icd_version', 'text'])
df_icd10 = df_icd10_grouped.agg({'text': 'first', 'icd_code': custom_agg, 'long_title': custom_agg}).reset_index(drop=True)
df_icd10.head()
# Out:
#                                                 text  \
# 0   \nName:  ___                    Unit No:   __...
# 1   \nName:  ___                 Unit No:   ___\n...
# 2   \nName:  ___                 Unit No:   ___\n...
# 3   \nName:  ___          Unit No:   ___\n \nAdmi...
# 4   \nName:  ___          Unit No:   ___\n \nAdmi...
#
#                                             icd_code  \
# 0            [G3183, F0280, R441, R296, E785, Z8546]
# 1  [R1310, R0989, K31819, K219, K449, F419, I341,...
# 2  [K219, F419, I341, M810, Z87891, S72012A, W010...
# 3  [K219, Z87891, N184, I2510, Z955, Z86718, I252...
# 4  [E785, Z87891, Z7901, N184, I2510, Z955, Z8671...
#
#                                           long_title
# 0  [Dementia with Lewy bodies, Dementia in other ...
# 1  [Dysphagia, unspecified, Other specified sympt...
# 2  [Gastro-esophageal reflux disease without esop...
# 3  [Gastro-esophageal reflux disease without esop...
# 4  [Hyperlipidemia, unspecified, Personal history...

# %%
lengths = [c for codes in df_icd10.icd_code.values for c in codes]
#sum(lengths)

# %%
len(lengths)
# Out:
# 1765371

# %%
len(set(lengths))
# Out:
# 16156

# %%
import collections
from collections import Counter
count = Counter(lengths)

# %%
codes_icd9 = [c for codes in df_icd9.icd_code.values for c in codes]
len(set(codes_icd9))
# Out:
# 8837

# %%
df = discharge.merge(diagnoses_icd_joined, on=['subject_id', 'hadm_id'])
df.drop(columns=['note_type', 'note_seq','charttime', 'storetime', 'seq_num'], inplace=True)
print("Dataset read.\n")
# 'note_id', 'subject_id', 'hadm_id', 'icd_code', 'icd_version', 'long_title'
df_icd9 = df[df.icd_version == 9].reset_index(drop=True)
df_icd10 = df[df.icd_version == 10].reset_index(drop=True)
#print(df_icd9.head())
#print(df_icd10.head())
#print(df_icd10.columns)
df_icd9_grouped = df_icd9.groupby(['note_id', 'subject_id', 'hadm_id', 'icd_version', 'text'])
df_icd9 = df_icd9_grouped.agg({'text': 'first', 'icd_code': custom_agg, 'long_title': custom_agg}).reset_index(drop=True)
#print(df_icd9.head())
#df_icd9_short = df_icd9[df_icd9['text'].apply(lambda x: len(word_tokenize(x))) <= 500]
df_icd9_short = df_icd9[df_icd9['text'].str.split().apply(len) <= 250]
print(df_icd9_short.iloc[0].text)
print(df_icd9_short.iloc[0].icd_code)
print(df_icd9_short.iloc[0].long_title)
print('*' * 100)
print(df_icd9_short.iloc[1].text)
print(df_icd9_short.iloc[1].icd_code)
print(df_icd9_short.ialoc[1].long_title)
print('*' * 100)
print(df_icd9_short.iloc[2].text)
print(df_icd9_short.iloc[2].icd_code)
print(df_icd9_short.iloc[2].long_title)
#df_icd9_short.to_csv('report_mimic_iv_250tok.csv', index=False)
""" 

print(df_icd9.iloc[0].text)
print(df_icd9.iloc[0].long_title)
print('-'*100)
print(df_icd9.iloc[1].text)
print(df_icd9.iloc[1].long_title)

radiology = pd.read_csv("data/physionet.org/files/mimic-iv-note/2.2/note/radiology.csv.gz", compression='gzip', encoding='utf-8')
# Print the text with newlines replaced

print(discharge.iloc[1].text)
print()
print(radiology.iloc[1].text)
print(discharge.columns == radiology.columns)
#print(data.shape)
"""

# %%
radiology = pd.read_csv("data/physionet.org/files/mimic-iv-note/2.2/note/radiology.csv.gz", compression='gzip', encoding='utf-8')
radiology.head()
# Out:
#           note_id  subject_id     hadm_id note_type  note_seq  \
# 0  10000032-RR-14    10000032  22595853.0        RR        14
# 1  10000032-RR-15    10000032  22595853.0        RR        15
# 2  10000032-RR-16    10000032  22595853.0        RR        16
# 3  10000032-RR-18    10000032         NaN        RR        18
# 4  10000032-RR-20    10000032         NaN        RR        20
#
#              charttime            storetime  \
# 0  2180-05-06 21:19:00  2180-05-06 23:32:00
# 1  2180-05-06 23:00:00  2180-05-06 23:26:00
# 2  2180-05-07 09:55:00  2180-05-07 11:15:00
# 3  2180-06-03 12:46:00  2180-06-03 14:01:00
# 4  2180-07-08 13:18:00  2180-07-08 14:15:00
#
#                                                 text
# 0  EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# 1  EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ...
# 2  INDICATION:  ___ HCV cirrhosis c/b ascites, hi...
# 3  EXAMINATION:  Ultrasound-guided paracentesis.\...
# 4  EXAMINATION:  Paracentesis\n\nINDICATION:  ___...

# %%
radiology.shape
# Out:
# (2321355, 8)

# %%
discharge.shape
# Out:
# (331793, 8)

# %%
print(radiology.iloc[0].text)
# Out:
# EXAMINATION:  CHEST (PA AND LAT)
#
# INDICATION:  ___ with new onset ascites  // eval for infection
#
# TECHNIQUE:  Chest PA and lateral
#
# COMPARISON:  None.
#
# FINDINGS:
#
# There is no focal consolidation, pleural effusion or pneumothorax.  Bilateral
# nodular opacities that most likely represent nipple shadows. The
# cardiomediastinal silhouette is normal.  Clips project over the left lung,
# potentially within the breast. The imaged upper abdomen is unremarkable.
# Chronic deformity of the posterior left sixth and seventh ribs are noted.
#
# IMPRESSION:
#
# No acute cardiopulmonary process.

# %%
df_radio = radiology.merge(diagnoses_icd_joined, on=['subject_id', 'hadm_id'])
df_radio
# Out:
#                  note_id  subject_id     hadm_id note_type  note_seq  \
# 0         10000032-RR-14    10000032  22595853.0        RR        14
# 1         10000032-RR-14    10000032  22595853.0        RR        14
# 2         10000032-RR-14    10000032  22595853.0        RR        14
# 3         10000032-RR-14    10000032  22595853.0        RR        14
# 4         10000032-RR-14    10000032  22595853.0        RR        14
# ...                  ...         ...         ...       ...       ...
# 19314580  19999987-RR-21    19999987  23865745.0        RR        21
# 19314581  19999987-RR-21    19999987  23865745.0        RR        21
# 19314582  19999987-RR-21    19999987  23865745.0        RR        21
# 19314583  19999987-RR-21    19999987  23865745.0        RR        21
# 19314584  19999987-RR-21    19999987  23865745.0        RR        21
#
#                     charttime            storetime  \
# 0         2180-05-06 21:19:00  2180-05-06 23:32:00
# ...

# %%
df_radio.drop(columns=['note_type', 'note_seq','charttime', 'storetime', 'seq_num'], inplace=True)
print("Dataset read.\n")
# 'note_id', 'subject_id', 'hadm_id', 'icd_code', 'icd_version', 'long_title'
df_icd9_radio = df_radio[df_radio.icd_version == 9].reset_index(drop=True)
df_icd10_radio = df_radio[df_radio.icd_version == 10].reset_index(drop=True)
df_icd10_radio
# Out:
# Dataset read.
#                 note_id  subject_id     hadm_id  \
# 0        10000084-RR-15    10000084  29888819.0
# 1        10000084-RR-15    10000084  29888819.0
# 2        10000084-RR-15    10000084  29888819.0
# 3        10000084-RR-15    10000084  29888819.0
# 4        10000084-RR-15    10000084  29888819.0
# ...                 ...         ...         ...
# 8617034  19999828-RR-27    19999828  25744818.0
# 8617035  19999828-RR-27    19999828  25744818.0
# 8617036  19999828-RR-27    19999828  25744818.0
# 8617037  19999828-RR-27    19999828  25744818.0
# 8617038  19999828-RR-27    19999828  25744818.0
#
#                                                       text icd_code  \
# 0        EXAMINATION:  CT HEAD W/O CONTRAST Q111 CT HEA...    F0280
# 1        EXAMINATION:  CT HEAD W/O CONTRAST Q111 CT HEA...     E785
# 2        EXAMINATION:  CT HEAD W/O CONTRAST Q111 CT HEA...    Z8546
# 3        EXAMINATION:  CT HEAD W/O CONTRAST Q111 CT HEA...    R4182
# ...

# %%
df_icd9_radio_grouped = df_icd9_radio.groupby(['note_id', 'subject_id', 'hadm_id', 'icd_version', 'text'])
df_icd9_radio = df_icd9_radio_grouped.agg({'text': 'first', 'icd_code': custom_agg, 'long_title': custom_agg}).reset_index(drop=True)
df_icd9_radio
# Out:
#                                                      text  \
# 0       EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# 1       EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ...
# 2       INDICATION:  ___ HCV cirrhosis c/b ascites, hi...
# 3       EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ...
# 4       EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# ...                                                   ...
# 704872  HISTORY:  ___, with left occipital bleeding.  ...
# 704873  INDICATION:  ___ female intubated for head ble...
# 704874  HISTORY:  ___ woman with left occipital hemorr...
# 704875  PORTABLE CHEST OF ___\n\nCOMPARISON:  ___ radi...
# 704876  DATE OF SERVICE:  ___.\n\nPRE-OPERATIVE DIAGNO...
#
#                                                  icd_code  \
# 0       [5723, 78959, 5715, 07070, 496, 29680, 30981, ...
# 1       [5723, 78959, 5715, 07070, 496, 29680, 30981, ...
# 2       [5723, 78959, 5715, 07070, 496, 29680, 30981, ...
# ...

# %%
df_icd10_radio_grouped = df_icd10_radio.groupby(['note_id', 'subject_id', 'hadm_id', 'icd_version', 'text'])
df_icd10_radio = df_icd10_radio_grouped.agg({'text': 'first', 'icd_code': custom_agg, 'long_title': custom_agg}).reset_index(drop=True)
df_icd10_radio
# Out:
#                                                      text  \
# 0       EXAMINATION:  CT HEAD W/O CONTRAST Q111 CT HEA...
# 1       EXAMINATION:   CHEST (PA AND LAT)\n\nINDICATIO...
# 2       EXAMINATION:   NECK SOFT TISSUES\n\nINDICATION...
# 3       EXAMINATION:  Left hip radiographs, two views,...
# 4       EXAMINATION:  Chest radiographs, PA and latera...
# ...                                                   ...
# 439431  INDICATION:  History: ___ with cough  // cough...
# 439432  EXAMINATION:  UNILAT LOWER EXT VEINS RIGHT\n\n...
# 439433  EXAMINATION:  SECOND OPINION CT TORSO\n\nINDIC...
# 439434  EXAMINATION:  CT ABDOMEN AND PELVIS WITH CONTR...
# 439435  EXAMINATION:  UNILAT LOWER EXT VEINS RIGHT\n\n...
#
#                                                  icd_code  \
# 0                  [F0280, E785, Z8546, R4182, G20, R609]
# 1       [R1310, R0989, K31819, K219, K449, F419, I341,...
# 2       [R1310, R0989, K31819, K219, K449, F419, I341,...
# ...

# %%
icd10_radio_codes = [c for codes in df_icd10_radio.icd_code.values for c in codes]
total = icd10_radio_codes + lengths
len(set(total))
# Out:
# 16437

# %%
len(set(lengths))
# Out:
# 16156

# %%
icd9_radio_codes = [c for codes in df_icd9_radio.icd_code.values for c in codes]
total = icd9_radio_codes + codes_icd9
len(set(total))
# Out:
# 8936

# %%
len(set(codes_icd9))
# Out:
# 8837

# %%
print("Radiography:", df_icd10_radio.shape[0])
print("Discharge:", df_icd10.shape[0])
print("Total:", df_icd10_radio.shape[0] + df_icd10.shape[0])
# Out:
# Radiography: 439436
# Discharge: 122300
# Total: 561736

# %%
print("Radiography:", df_icd9_radio.shape[0])
print("Discharge:", df_icd9.shape[0])
print("Total:", df_icd9_radio.shape[0] + df_icd9.shape[0])
# Out:
# Radiography: 704877
# Discharge: 209352
# Total: 914229

# %%
df_icd10_radio.iloc[0].long_title
# Out:
# ['Dementia in other diseases classified elsewhere without behavioral disturbance',
#  'Hyperlipidemia, unspecified',
#  'Personal history of malignant neoplasm of prostate',
#  'Altered mental status, unspecified',
#  "Parkinson's disease",
#  'Edema, unspecified']

# %%
df_icd10_radio.iloc[0].icd_code
# Out:
# ['F0280', 'E785', 'Z8546', 'R4182', 'G20', 'R609']

# %%
cd1 = list(df_icd10_radio.icd_code.values)
cd2 = list(df_icd10.icd_code.values)
assignable_code_mimic = []
for c in cd1:
    assignable_code_mimic += c
for c in cd2:
    assignable_code_mimic += c  

len(set(assignable_code_mimic))
# Out:
# 16437

# %%
from collections import Counter
count_codes = Counter(assignable_code_mimic)

# %%
print(len(all_codes_mimic), len(all_codes_2020))
# Out:
# 95109 94765

# %%
len(set(all_codes_mimic).difference(set(all_codes_2020)))
# Out:
# 344

# %%
old_version_codes = set(assignable_code_mimic).difference(set(all_codes_2020))
for cd in old_version_codes:
    print(cd, count_codes[cd])
# Out:
# T84041A 100
# S030XXA 32
# T8584XA 61
# I6022 151
# T670XXA 66
# H8142 2
# S0261XA 52
# V4712XA 35
# H4011X2 16
# S0261XB 3
# S028XXB 4
# V4752XD 2
# V4792XA 8
# I6020 50
# T84040A 122
# S0210XA 11
# T8585XA 7
# S028XXD 19
# S023XXD 21
# V4751XA 24
# T814XXA 9206
# S023XXA 504
# Z2259 9
# Z2252 24
# T814XXD 86
# I6021 22
# S0265XK 4
# S0262XB 6
# S0264XB 4
# T84040S 9
# T8351XA 1321
# S0265XA 60
# T84048A 27
# S023XXS 6
# T84043A 22
# H4011X0 114
# S0265XB 10
# H8143 3
# V4762XA 78
# T8359XA 66
# S028XXA 539
# S0267XA 31
# Z2251 102
# T836XXA 8
# V4702XA 43
# S0263XA 9
# T8586XA 121
# S0262XA 33
# V4752XA 282
# T8583XA 20
# T84040D 19
# T84042A 39
# T84041S 4
# T8582XA 3
# T8589XA 176
# S63144A 10
# T8351XD 2
# S0264XA 90
# H8149 59

# %%
# Out:
# 3

# %%
code2title['H4011X0']
# Out:
# 'Primary open-angle glaucoma, stage unspecified'

# %%
conversion = pd.read_excel('icd_db/2020/code_descriptions/ICD-10-CM-Conversion-Table-FY20.xlsx', skiprows=1)
conversion.head()

old2new = {old: new for old, new in zip(conversion['Previous Code(s) Assignment'].values, conversion['Current code assignment'].values)}

# %%
len(old2new)
# Out:
# 995

# %%
missing
# Out:
# {'H4011X0',
#  'H4011X2',
#  'H8142',
#  'H8143',
#  'H8149',
#  'I6020',
#  'I6021',
#  'I6022',
#  'S0210XA',
#  'S023XXA',
#  'S023XXD',
#  'S023XXS',
#  'S0261XA',
#  'S0261XB',
#  'S0262XA',
#  'S0262XB',
#  'S0263XA',
#  'S0264XA',
#  'S0264XB',
#  'S0265XA',
#  'S0265XB',
#  'S0265XK',
#  'S0267XA',
#  'S028XXA',
#  'S028XXB',
#  'S028XXD',
#  'S030XXA',
#  'S63144A',
#  'T670XXA',
#  'T814XXA',
#  'T814XXD',
#  'T8351XA',
#  'T8351XD',
#  'T8359XA',
#  'T836XXA',
#  'T84040A',
#  'T84040D',
#  'T84040S',
#  'T84041A',
#  'T84041S',
#  'T84042A',
#  'T84043A',
#  'T84048A',
#  'T8582XA',
#  'T8583XA',
#  'T8584XA',
#  'T8585XA',
#  'T8586XA',
#  'T8589XA',
#  'V4702XA',
#  'V4712XA',
#  'V4751XA',
#  'V4752XA',
#  'V4752XD',
#  'V4762XA',
#  'V4792XA',
#  'Z2251',
#  'Z2252',
#  'Z2259'}

# %%
xx = list(conversion['Previous Code(s) Assignment'].values)
for x in xx:
    if x.startswith("T83.51"):
        print(x)
# Out:
# T83.51XA
# T83.51XD
# T83.51XS
# T83.51XA
# T83.51XD
# T83.51XS
# T83.51XA
# T83.51XD
# T83.51XS
# T83.51XA
# T83.51XD
# T83.51XS

# %%
old2new['T83.51XA']
# Out:
# 'T83.518A'

# %%
missing = set(assignable_code_mimic).difference(set(all_codes_2020))
missing.difference(set([key.replace('.','') for key in old2new.keys()]))
# Out:
# {'H8142',
#  'H8143',
#  'H8149',
#  'I6020',
#  'I6021',
#  'I6022',
#  'S63144A',
#  'V4702XA',
#  'V4712XA',
#  'V4751XA',
#  'V4752XA',
#  'V4752XD',
#  'V4762XA',
#  'V4792XA',
#  'Z2251',
#  'Z2252',
#  'Z2259'}

# %%
set(assignable_code_mimic).intersection(set(no_assignable_codes_2020))
# Out:
# set()

# %%
import pandas as pd
df_icd9 = pd.read_feather('./Split/mimiciv_icd9/mimiciv_icd9.feather')
df_icd9
# Out:
#                note_id  subject_id       _id note_type  note_seq  \
# 0       10000032-DS-21    10000032  22595853        DS        21
# 1       10000032-DS-22    10000032  22841357        DS        22
# 2       10000032-DS-23    10000032  29079034        DS        23
# 3       10000032-DS-24    10000032  25742920        DS        24
# 4       10000248-DS-10    10000248  20600184        DS        10
# ...                ...         ...       ...       ...       ...
# 209321  19999625-DS-12    19999625  27638769        DS        12
# 209322  19999625-DS-13    19999625  25304202        DS        13
# 209323  19999840-DS-20    19999840  26071774        DS        20
# 209324  19999840-DS-21    19999840  21033226        DS        21
# 209325   19999987-DS-2    19999987  23865745        DS         2
#
#                   charttime            storetime  \
# 0       2180-05-07 00:00:00  2180-05-09 15:26:00
# 1       2180-06-27 00:00:00  2180-07-01 10:15:00
# ...

# %%
df_icd9.loc[0].text
# Out:
# 'name unit no admission date discharge date date of birth sex f service medicine allergies no known allergies adverse drug reactions attending chief complaint worsening abd distension and pain major surgical or invasive procedure paracentesis history of present illness hcv cirrhosis c b ascites hiv on art h o ivdu copd bioplar ptsd presented from osh ed with worsening abd distension over past week pt reports self discontinuing lasix and spirnolactone weeks ago because she feels like they don t do anything and that she doesn t want to put more chemicals in her she does not follow na restricted diets in the past week she notes that she has been having worsening abd distension and discomfort she denies edema or sob or orthopnea she denies f c n v d c dysuria she had food poisoning a week ago from eating stale cake n v min after food ingestion which resolved the same day she denies other recent illness or sick contacts she notes that she has been noticing gum bleeding while brushing her 
# ...

# %%
import pandas as pd
df_icd10 = pd.read_feather('files/data/mimiciv_icd10/mimiciv_icd10.feather')
df_icd10
# Out:
#                note_id  subject_id       _id note_type  note_seq  \
# 0       10000084-DS-17    10000084  23052089        DS        17
# 1       10000117-DS-21    10000117  22927623        DS        21
# 2       10000117-DS-22    10000117  27988844        DS        22
# 3       10000980-DS-24    10000980  25911675        DS        24
# 4       10000980-DS-25    10000980  29659838        DS        25
# ...                ...         ...       ...       ...       ...
# 122273   19999784-DS-7    19999784  26194817        DS         7
# 122274   19999784-DS-8    19999784  24935234        DS         8
# 122275   19999784-DS-9    19999784  23664472        DS         9
# 122276   19999828-DS-6    19999828  29734428        DS         6
# 122277   19999828-DS-7    19999828  25744818        DS         7
#
#                   charttime            storetime  \
# 0       2160-11-25 00:00:00  2160-11-25 15:09:00
# 1       2181-11-15 00:00:00  2181-11-15 15:04:00
# ...

# %%
d_icd_diagnoses = pd.read_csv("data/physionet.org/files/mimiciv/2.2/hosp/d_icd_diagnoses.csv.gz", compression="gzip")
d_icd10_diagnoses = d_icd_diagnoses[d_icd_diagnoses.icd_version==10]

# %%
d_icd_procedures = pd.read_csv("data/physionet.org/files/mimiciv/2.2/hosp/d_icd_procedures.csv.gz", compression="gzip")
d_icd10_procedures = d_icd_procedures[d_icd_procedures.icd_version==10]

# %%
import numpy as np
df_icd10_total = pd.concat([d_icd10_diagnoses, d_icd10_procedures], axis = 0)
df_icd10_total
# Out:
#       icd_code  icd_version                                         long_title
# 12238      A00           10                                            Cholera
# 12239     A000           10  Cholera due to Vibrio cholerae 01, biovar chol...
# 12240     A001           10    Cholera due to Vibrio cholerae 01, biovar eltor
# 12241     A009           10                               Cholera, unspecified
# 12242      A01           10                     Typhoid and paratyphoid fevers
# ...        ...          ...                                                ...
# 85252  XW0DXV5           10  Introduction of Gilteritinib Antineoplastic in...
# 85253      XXE           10  New Technology, Physiological Systems, Measure...
# 85254  XXE5XM5           10  Measurement of Infection, Whole Blood Nucleic ...
# 85255      XY0           10       New Technology, Extracorporeal, Introduction
# 85256  XY0VX83           10  Extracorporeal Introduction of Endothelial Dam...
#
# ...

# %%
cod2lbl = {}
for key, value in zip(df_icd10_total.icd_code, df_icd10_total.long_title):
    cod2lbl[key]=value

# %%
def assign_title(x):
    return [cod2lbl[el.replace('.', '')] for el in x]

# %%
df_icd10['descriptions'] = df_icd10['target'].map(assign_title)
df_icd10.head(5)
# Out:
#           note_id  subject_id       _id note_type  note_seq  \
# 0  10000084-DS-17    10000084  23052089        DS        17
# 1  10000117-DS-21    10000117  22927623        DS        21
# 2  10000117-DS-22    10000117  27988844        DS        22
# 3  10000980-DS-24    10000980  25911675        DS        24
# 4  10000980-DS-25    10000980  29659838        DS        25
#
#              charttime            storetime  \
# 0  2160-11-25 00:00:00  2160-11-25 15:09:00
# 1  2181-11-15 00:00:00  2181-11-15 15:04:00
# 2  2183-09-21 00:00:00  2183-09-29 16:23:00
# 3  2191-05-24 00:00:00  2191-05-24 17:29:00
# 4  2191-07-19 00:00:00  2191-07-22 09:37:00
#
#                                                 text icd10_proc  \
# 0  name unit no admission date discharge date dat...         []
# 1  name unit no admission date discharge date dat...         []
# 2  name unit no admission date discharge date dat...  [0QS734Z]
# 3  name unit no admission date discharge date dat...         []
# ...

# %%
df_icd10.iloc[2].text
# Out:
# 'name unit no admission date discharge date date of birth sex f service orthopaedics allergies omeprazole iodine and iodide containing products hallucinogens attending chief complaint left hip pain major surgical or invasive procedure status post left crpp history of present illness reason for consult femur fracture hpi female presents with the above fracture s p mechanical fall this morning pt was walking when dog pulled on leash pt fell on l hip immediate pain with movement denies head strike loc or blood thinners denies numbness or weakness in the extremities past medical history gerd hypercholesterolemia kidney stones mitral valve prolapse uterine fibroids osteoporosis migraine headaches social history family history htn father dementia father physical exam general well appearing female in no acute distress left lower extremity skin intact no deformity edema ecchymosis erythema induration soft non tender thigh and leg full painless rom knee and ankle fires silt s s sp dp t distri
# ...

# %%
lengths = df_icd10.num_words
np.average(lengths)
# Out:
# 1596.879217847855

# %%
from transformers import AutoTokenizer
from huggingface_hub import login
login(token='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')
tok = AutoTokenizer.from_pretrained('epfl-llm/meditron-7b')
# Out:
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
lengths_tok = [len(tok(text).input_ids) for text in df_icd10.text]
np.average(lengths_tok)
# Out:
# 2516.0469095013004

# %%
import pandas as pd
df_icd10_clean = pd.read_feather('files/data/mimiciv_icd10/mimiciv_icd10.feather')
df_icd10_clean
# Out:
#                note_id  subject_id       _id note_type  note_seq  \
# 0       10000084-DS-17    10000084  23052089        DS        17
# 1       10000117-DS-21    10000117  22927623        DS        21
# 2       10000117-DS-22    10000117  27988844        DS        22
# 3       10000980-DS-24    10000980  25911675        DS        24
# 4       10000980-DS-25    10000980  29659838        DS        25
# ...                ...         ...       ...       ...       ...
# 122273   19999784-DS-7    19999784  26194817        DS         7
# 122274   19999784-DS-8    19999784  24935234        DS         8
# 122275   19999784-DS-9    19999784  23664472        DS         9
# 122276   19999828-DS-6    19999828  29734428        DS         6
# 122277   19999828-DS-7    19999828  25744818        DS         7
#
#                   charttime            storetime  \
# 0       2160-11-25 00:00:00  2160-11-25 15:09:00
# 1       2181-11-15 00:00:00  2181-11-15 15:04:00
# ...

# %%
assignable_code_mimic_clean =list(df_icd10_clean.icd10_diag.values)
assignable_code_mimic_clean = [code.replace('.','') for codes in assignable_code_mimic_clean for code in codes]
print(len(set(assignable_code_mimic_clean)))
len(set(assignable_code_mimic_clean).difference(assignable_codes_2020))
# Out:
# 5803
# 86

# %%
import pandas as pd
d_icd_diagnoses = pd.read_csv("data/physionet.org/files/mimiciv/2.2/hosp/d_icd_diagnoses.csv.gz", compression="gzip")
d_icd10 = d_icd_diagnoses[d_icd_diagnoses.icd_version==10]

# %%
d_icd10
# Out:
#        icd_code  icd_version  \
# 12238       A00           10
# 12239      A000           10
# 12240      A001           10
# 12241      A009           10
# 12242       A01           10
# ...         ...          ...
# 109770     Z992           10
# 109771     Z993           10
# 109772     Z998           10
# 109773    Z9981           10
# 109774    Z9989           10
#
#                                                long_title
# 12238                                             Cholera
# 12239   Cholera due to Vibrio cholerae 01, biovar chol...
# 12240     Cholera due to Vibrio cholerae 01, biovar eltor
# 12241                                Cholera, unspecified
# 12242                      Typhoid and paratyphoid fevers
# ...                                                   ...
# 109770                       Dependence on renal dialysis
# 109771                           Dependence on wheelchair
# 109772  Dependence on other enabling machines and devices
# ...

# %%
all_codes_mimic = list(d_icd10.icd_code.values)
len(all_codes_mimic)
code2title = {key: value for key,value in zip(d_icd10.icd_code.values, d_icd10.long_title.values)}

# %%
with open('icd_db/2020/code_descriptions/icd10cm_codes_2020.txt') as f:
    lines = f.readlines()
codes = [line.split(' ')[0] for line in lines]

# %%
len(codes)
# Out:
# 72184

# %%
for i, line in enumerate(lines):
    try:
        oo = line.split('  ')[1].strip()
    except:
        print(i)
        break
# Out:
# 1300

# %%
for line in lines:
    if len(line.split()[0]) == 6:
        code = " ".join(line.split()[1:]).strip()

# %%
len(d_icd10.icd_code.values)
# Out:
# 95109

# %%
set(d_icd10.icd_code.values).difference(set(codes))
# Out:
# {'T486X6',
#  'S95111',
#  'S900',
#  'T2252',
#  'V274',
#  'V3949',
#  'B51',
#  'W268',
#  'T361X6',
#  'Y3610',
#  'S72411',
#  'S91042',
#  'S23101',
#  'T234',
#  'T678',
#  'S370',
#  'V149',
#  'T81597',
#  'S36221',
#  'V189',
#  'S62014',
#  'V332',
#  'S96992',
#  'T425X',
#  'G31',
#  'W65',
#  'S3313',
#  'S71042',
#  'S9302',
#  'S22039',
#  'K570',
#  'Y35121',
#  'S56423',
#  'K800',
#  'T5992',
#  'M9081',
#  'T84210',
#  'S48111',
#  'S565',
#  'V0920',
#  'E111',
#  'G570',
#  'T40603',
#  'T63822',
#  'V863',
#  'D143',
#  'S53101',
#  'J45',
#  'T14',
#  'M1011',
#  'S62335',
#  'T467X6',
#  'S36539',
#  'N81',
#  'T492X4',
#  'M1A149',
#  'S14128',
#  'T189',
#  'T22192',
#  'T25291',
#  'V8002',
#  'C340',
#  'S069X6',
#  'W16322',
#  'T5792',
#  'X151',
#  'S4102',
#  'X98',
#  'T5994',
#  'N92',
#  'S55011',
#  'S066',
#  'M80072',
#  'T276',
#  'S6401',
#  'S062X8',
#  'N997',
#  'T81592',
#  'I95',
#  'S61306',
#  'S13110',
#  'S61222',
#  'T82514',
# ...

# %%
'S95111A' in codes
# Out:
# True

# %%
codes
# Out:
# ['A000',
#  'A001',
#  'A009',
#  'A0100',
#  'A0101',
#  'A0102',
#  'A0103',
#  'A0104',
#  'A0105',
#  'A0109',
#  'A011',
#  'A012',
#  'A013',
#  'A014',
#  'A020',
#  'A021',
#  'A0220',
#  'A0221',
#  'A0222',
#  'A0223',
#  'A0224',
#  'A0225',
#  'A0229',
#  'A028',
#  'A029',
#  'A030',
#  'A031',
#  'A032',
#  'A033',
#  'A038',
#  'A039',
#  'A040',
#  'A041',
#  'A042',
#  'A043',
#  'A044',
#  'A045',
#  'A046',
#  'A0471',
#  'A0472',
#  'A048',
#  'A049',
#  'A050',
#  'A051',
#  'A052',
#  'A053',
#  'A054',
#  'A055',
#  'A058',
#  'A059',
#  'A060',
#  'A061',
#  'A062',
#  'A063',
#  'A064',
#  'A065',
#  'A066',
#  'A067',
#  'A0681',
#  'A0682',
#  'A0689',
#  'A069',
#  'A070',
#  'A071',
#  'A072',
#  'A073',
#  'A074',
#  'A078',
#  'A079',
#  'A080',
#  'A0811',
#  'A0819',
#  'A082',
#  'A0831',
#  'A0832',
#  'A0839',
#  'A084',
#  'A088',
#  'A09',
#  'A150',
#  'A154',
#  'A155',
#  'A156',
#  'A157',
#  'A158',
#  'A159',
#  'A170',
#  'A171',
# ...

# %%
with open('icd_db/2020/code_descriptions/icd10cm_order_2020.txt') as f:
    lines2 = f.readlines()

# %%
all_codes_2020 = [line.split()[0] for line in lines2]

# %%
import re
no_assignable_codes_2020 = []
for line in lines2:
    line = re.sub(' +', ' ', line).strip()
    if int(line.split()[2]) == 0:
        no_assignable_codes_2020.append(line.split()[0])
len(no_assignable_codes_2020)
# Out:
# 22581

# %%
len(all_codes_2020)
# Out:
# 94765

# %%
with open('icd_db/2020/code_descriptions/icd10cm_codes_2020.txt') as f:
    lines3 = f.readlines()
assignable_codes_2020 = [line.split()[0] for line in lines3]
len(assignable_codes_2020)
# Out:
# 72184

# %%
len(set(all_codes).intersection(set(d_icd10.icd_code.values)))
# Out:
# 94765

# %%
set(all_codes_mimic).difference(set(all_codes_2020))
# Out:
# {'H4011X0',
#  'H4011X1',
#  'H4011X2',
#  'H4011X3',
#  'H4011X4',
#  'H8141',
#  'H8142',
#  'H8143',
#  'H8149',
#  'I6020',
#  'I6021',
#  'I6022',
#  'S0210XA',
#  'S0210XB',
#  'S0210XD',
#  'S0210XG',
#  'S0210XK',
#  'S0210XS',
#  'S023XXA',
#  'S023XXB',
#  'S023XXD',
#  'S023XXG',
#  'S023XXK',
#  'S023XXS',
#  'S0261XA',
#  'S0261XB',
#  'S0261XD',
#  'S0261XG',
#  'S0261XK',
#  'S0261XS',
#  'S0262XA',
#  'S0262XB',
#  'S0262XD',
#  'S0262XG',
#  'S0262XK',
#  'S0262XS',
#  'S0263XA',
#  'S0263XB',
#  'S0263XD',
#  'S0263XG',
#  'S0263XK',
#  'S0263XS',
#  'S0264XA',
#  'S0264XB',
#  'S0264XD',
#  'S0264XG',
#  'S0264XK',
#  'S0264XS',
#  'S0265XA',
#  'S0265XB',
#  'S0265XD',
#  'S0265XG',
#  'S0265XK',
#  'S0265XS',
#  'S0267XA',
#  'S0267XB',
#  'S0267XD',
#  'S0267XG',
#  'S0267XK',
#  'S0267XS',
#  'S028XXA',
#  'S028XXB',
#  'S028XXD',
#  'S028XXG',
#  'S028XXK',
#  'S028XXS',
#  'S030XXA',
#  'S030XXD',
#  'S030XXS',
#  'S034XXA',
#  'S034XXD',
#  'S034XXS',
# ...

# %%
code2title['H4011X0']
# Out:
# 'Primary open-angle glaucoma, stage unspecified'

# %%
set(d_icd10.icd_code.values).intersection(set(all_codes))
# Out:
# {'C964',
#  'S25412A',
#  'S95111',
#  'M50223',
#  'S56128S',
#  'V274',
#  'Z9484',
#  'H00035',
#  'J13',
#  'Y9349',
#  'S61202S',
#  'S60141D',
#  'R850',
#  'S95209D',
#  'B51',
#  'S22088A',
#  'S82236D',
#  'Z87441',
#  'Q303',
#  'H18323',
#  'S42014P',
#  'T17418S',
#  'S83123S',
#  'M11119',
#  'S85169D',
#  'S72412S',
#  'Y3610',
#  'S72411',
#  'I63349',
#  'M24076',
#  'S23101',
#  'S91002S',
#  'T234',
#  'S370',
#  'Z781',
#  'T81597',
#  'S56108S',
#  'V7940XD',
#  'F528',
#  'T602X3D',
#  'M89722',
#  'S36221',
#  'V9535XA',
#  'D822',
#  'V189',
#  'S62014',
#  'V332',
#  'T71143S',
#  'V412XXA',
#  'G31',
#  'O365939',
#  'T596X2A',
#  'S60819A',
#  'Q6632',
#  'S3313',
#  'K732',
#  'S5490XA',
#  'S63125A',
#  'G500',
#  'S42222S',
#  'S71042',
#  'S9302',
#  'Y35121',
#  'V0009XA',
#  'S56423',
#  'S52629P',
#  'T22522S',
#  'I69221',
#  'M9081',
#  'T23361S',
#  'V9313XD',
#  'T84210',
#  'S82032B',
#  'S52109A',
#  'S92531K',
#  'T382X3A',
#  'S92233B',
# ...

# %%
len(d_icd10.icd_code.values)
# Out:
# 95109

# %%
total = []
for codes10 in df_icd10.icd10_diag.values:
    total += list(codes10)

# %%
len(set(total))
# Out:
# 5803

# %%
set([el.replace('.','') for el in total]).difference(set(codes))
# Out:
# {'A047',
#  'E10359',
#  'E11329',
#  'E11359',
#  'E780',
#  'E784',
#  'F328',
#  'F42',
#  'F508',
#  'F53',
#  'G513',
#  'G710',
#  'H4011X0',
#  'H540',
#  'H5412',
#  'H5441',
#  'H5442',
#  'H578',
#  'H8149',
#  'I272',
#  'I481',
#  'I482',
#  'I638',
#  'I6931',
#  'I9762',
#  'J985',
#  'K088',
#  'K352',
#  'K353',
#  'K3589',
#  'K550',
#  'K565',
#  'K5660',
#  'K5669',
#  'K613',
#  'K830',
#  'K851',
#  'K852',
#  'K853',
#  'K858',
#  'K859',
#  'K868',
#  'K913',
#  'M2660',
#  'M4806',
#  'M5002',
#  'M5012',
#  'M5022',
#  'M5032',
#  'M791',
#  'N359',
#  'N508',
#  'N61',
#  'N63',
#  'N831',
#  'N8320',
#  'N8329',
#  'O001',
#  'O3421',
#  'O860',
#  'Q796',
#  'Q871',
#  'R312',
#  'R3919',
#  'R827',
#  'R8299',
#  'R938',
#  'R972',
#  'S023XXA',
#  'S0261XA',
#  'S0265XA',
#  'S028XXA',
#  'T148',
#  'T1490',
#  'T1491',
#  'T814XXA',
#  'T814XXD',
#  'T8351XA',
#  'T84040A',
#  'T84041A',
#  'T8584XA',
#  'T8586XA',
#  'T8589XA',
#  'V4752XA',
# ...

# %%
total
# Out:
# ['E78.5',
#  'F02.80',
#  'G31.83',
#  'R29.6',
#  'R44.1',
#  'Z85.46',
#  'F41.9',
#  'I34.1',
#  'K21.9',
#  'K31.819',
#  'K44.9',
#  'M81.0',
#  'R09.89',
#  'R13.10',
#  'Z87.891',
#  'E78.00',
#  'F41.9',
#  'G43.909',
#  'I34.1',
#  'K21.9',
#  'M81.0',
#  'S72.012A',
#  'W01.0XXA',
#  'Y92.480',
#  'Z79.01',
#  'Z87.442',
#  'Z87.891',
#  'D50.0',
#  'E11.8',
#  'I12.9',
#  'I25.10',
#  'I25.2',
#  'I50.23',
#  'I70.218',
#  'K21.9',
#  'K22.2',
#  'K25.9',
#  'K29.70',
#  'K57.30',
#  'N18.4',
#  'R07.89',
#  'R79.1',
#  'T45.515A',
#  'Z23.',
#  'Z79.4',
#  'Z86.718',
#  'Z86.73',
#  'Z87.891',
#  'Z95.5',
#  'D63.1',
#  'E11.21',
#  'E78.5',
#  'I12.9',
#  'I25.10',
#  'I25.2',
#  'I34.0',
#  'I50.23',
#  'N18.4',
#  'Z79.01',
#  'Z79.4',
#  'Z86.718',
#  'Z86.73',
#  'Z87.891',
#  'Z91.128',
#  'Z95.5',
#  'D64.89',
#  'E11.22',
#  'E11.319',
#  'E11.51',
#  'E66.9',
#  'E78.5',
#  'E87.2',
#  'G47.00',
#  'I13.0',
#  'I25.10',
#  'I25.2',
#  'I50.33',
#  'M1A.9XX0',
# ...
