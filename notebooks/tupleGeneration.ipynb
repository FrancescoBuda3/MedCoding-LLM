# %%
# !pip install simple-icd-10-cm
# Out:
# Requirement already satisfied: simple-icd-10-cm in c:\users\buda2\anaconda3\lib\site-packages (1.2.0)

# %%
OUTPUT_DIR = "./../output/datasets/"
DATA_DIR = "./../data/"

# %%
import simple_icd_10_cm as cm
import pandas as pd
import numpy as np
import json
import random

# %%
diagnoses = pd.read_csv(DATA_DIR + "d_icd_diagnoses.csv.gz", compression="gzip")
diagnoses = diagnoses[diagnoses["icd_version"] == 10]

cod2ents = {}
desc2cod = {}
cod2desc = {}

for index, row in diagnoses.iterrows():
    cod2ents[row["icd_code"]] = set()
    desc2cod[row["long_title"]] = row["icd_code"]
    cod2desc[row["icd_code"]] = row["long_title"]




pp = []
data = {}
with open(OUTPUT_DIR + "pairs.jsonl", 'r') as f:
    for line in f:
        line = json.loads(line)
        id = line["note_id"]
        pairs = line["pairs"]
        pairsList = []
        for pair in pairs:
            if pair["label"] in desc2cod:
                cod2ents[desc2cod[pair["label"]]].add(pair["term"].upper())
                pp.append((pair["term"], desc2cod[pair["label"]]))
                pairsList.append((pair["term"], desc2cod[pair["label"]]))
        if id not in data:
            data[id] = []
        data[id] += pairsList

pairs = pp

# %%
# a partire dal dictionary data crea un dataframe di pandas, senza usare il metodo append

dd = []

for k, v in data.items():
    dd.append((k, v, list(set([touple[1] for touple in v]))))

df = pd.DataFrame(dd, columns=["note_id", "pairs", "anchoredCodes"])

# %%
notes = pd.read_feather(DATA_DIR + "mimiciv_icd10.feather")

# %%
df = pd.merge(df, notes, on="note_id", how="left")

# %%
# Out:
# 28805

# %%
missingCodesPerNote = 0
totalCodes = set()
totalAnchoredCodes = set()
totalMissingCodes = set()
for index, row in df.iterrows():
    codes = set([x.replace(".","") for x in row["icd10_diag"]])
    anchoredCodes = set(row["anchoredCodes"])
    #anchoredCodes = anchoredCodes.intersection(codes)
    missingCodes = codes - anchoredCodes
    missingCodesPerNote += len(missingCodes)
    totalCodes = totalCodes.union(codes)
    totalAnchoredCodes = totalAnchoredCodes.union(anchoredCodes)

missingCodesPerNote /= len(df)
totalMissingCodes = totalCodes - totalAnchoredCodes
print("Missing codes per note: ", missingCodesPerNote)
print("Total missing codes: ", len(totalMissingCodes))
print("Total codes: ", len(totalCodes))
print("Total anchored codes: ", len(totalAnchoredCodes))
# Out:
# Missing codes per note:  5.587593879568559
# Total missing codes:  129
# Total codes:  5799
# Total anchored codes:  5959

# %%
t = [cod2desc[x] for x in (totalAnchoredCodes - totalCodes)]

# %%
t
# Out:
# ['Diffuse large B-cell lymphoma',
#  'Alcoholic liver disease',
#  'Emphysema',
#  'Diseases of the digestive system complicating pregnancy',
#  'Nicotine dependence',
#  'Dysphagia',
#  'Exotropia',
#  'Acute respiratory failure',
#  'Diaphragmatic hernia',
#  'Myositis',
#  'Chronic kidney disease (CKD)',
#  'Preterm labor second trimester with preterm delivery second trimester',
#  'Osteophyte',
#  'Malignant neoplasm of retroperitoneum and peritoneum',
#  'Epilepsy, unspecified, intractable',
#  'Brucellosis',
#  'Major depressive disorder, recurrent',
#  'Malignant neoplasm of bronchus and lung',
#  'Vitamin A deficiency',
#  'Traumatic pneumothorax',
#  'Irritable bowel syndrome',
#  'Bilateral inguinal hernia, without obstruction or gangrene',
#  'Osteonecrosis',
#  'Fall from, out of or through roof',
#  'Alcoholic cirrhosis of liver',
#  'Periprosthetic fracture around internal prosthetic left knee joint, initial encounter',
#  'Hypotension',
#  'Abdominal tenderness',
#  'Scleritis',
#  'Presence of artificial knee joint',
#  'Hepatic failure, unspecified',
#  "Meniere's disease",
#  'Bence Jones proteinuria',
#  'Traumatic subarachnoid hemorrhage',
#  'Nontraumatic intracerebral hemorrhage',
#  "Crohn's disease, unspecified",
#  'Other specified diseases of stomach and duodenum',
#  'Thiamine deficiency',
#  'Dystonia',
#  'Sialoadenitis',
#  'Lyme disease',
#  'Long term (current) drug therapy',
#  'Other disorders of peritoneum',
#  'Unspecified nondisplaced fracture of sixth cervical vertebra',
#  'Infection of amputation stump',
#  'Bloodstream infection due to central venous catheter',
#  'Vitamin D deficiency',
#  'Other specified types of non-Hodgkin lymphoma',
#  'Traumatic subdural hemorrhage with loss of consciousness of unspecified duration',
#  'Cholelithiasis',
#  'Myasthenia gravis',
#  'Malignant neoplasm of cervix uteri',
#  'Urinary tract infection following delivery',
#  'Chorioamnionitis',
#  'Type 1 diabetes mellitus',
#  'Labyrinthitis',
#  'Constipation',
#  'Severe pre-eclampsia',
#  'Secondary malignant neoplasm of lung',
#  'Other spondylosis with radiculopathy',
#  'Unspecified atherosclerosis of native arteries of extremities',
#  'Personal history of malignant neoplasm of large intestine',
#  'Acute sinusitis',
#  'Atopic dermatitis',
#  'Seborrheic keratosis',
#  'Tetralogy of Fallot',
#  'Unspecified asthma',
#  'Gestational diabetes mellitus in childbirth',
#  'Preterm labor',
#  'Vitamin B12 deficiency anemia',
#  'Atherosclerotic heart disease of native coronary artery',
#  'Acute kidney failure',
#  'Adverse effect of antineoplastic and immunosuppressive drugs',
#  'Secondary and unspecified malignant neoplasm of lymph nodes',
#  'Duodenitis',
#  'Graft-versus-host disease',
#  'Other disorders of muscle',
#  'Dysplasia of cervix uteri',
#  'Major depressive disorder, single episode',
#  'Carpal tunnel syndrome',
#  'Nontraumatic subarachnoid hemorrhage',
#  'Postpartum hemorrhage',
#  'Situs inversus',
#  'Seborrheic dermatitis',
#  'Asthma',
#  'Myeloid sarcoma',
#  'Down syndrome',
#  'Osteonecrosis in diseases classified elsewhere',
#  'Spondylosis',
#  'Opioid abuse',
#  'Other postprocedural states',
#  'Osteomyelitis',
#  'Placenta previa',
#  'Other spondylosis with myelopathy',
#  'Viral meningitis',
#  'Hypertensive crisis',
#  'Iron deficiency anemia',
#  'Atherosclerosis',
#  'Other bacterial agents as the cause of diseases classified elsewhere',
#  'Bronchiectasis',
#  'Otitis media, unspecified',
#  'Opioid use, unspecified',
#  'Obstructive and reflux uropathy',
#  'Elevated white blood cell count',
#  'Acute and subacute hepatic failure',
#  'Gastro-esophageal reflux disease',
#  'Otitis externa',
#  'Microscopic colitis',
#  'Preterm labor third trimester with preterm delivery third trimester',
#  'Pathological fracture in neoplastic disease, other specified site',
#  'Other injury of other intra-abdominal organs',
#  'Primary hyperoxaluria',
#  'Sarcoidosis',
#  'Acute myeloblastic leukemia',
#  'Anemia complicating pregnancy',
#  'Hairy cell leukemia',
#  'Tularemia',
#  'Traumatic hemorrhage of left cerebrum',
#  'Chronic sinusitis',
#  'Chronic respiratory failure',
#  'Pancytopenia',
#  'Polymyositis',
#  'Nephrotic syndrome',
#  'Angioneurotic edema',
#  'Aggressive systemic mastocytosis',
#  'Aspergillosis',
#  'Anorexia nervosa',
#  'Acute pharyngitis',
#  'Cardiac arrest',
#  'Eosinophilic colitis',
#  'Post-traumatic stress disorder (PTSD)',
#  'Manic episode',
#  'Migraine with aura',
#  'Disseminated aspergillosis',
#  'Ulcerative colitis',
#  "Marfan's syndrome",
#  'Adverse effect of other opioids',
#  'Pemphigoid',
#  'Spinal stenosis',
#  'Other fall from one level to another',
#  'Toxoplasmosis',
#  'Malignant neoplasm of pancreas',
#  'Adverse effect of insulin and oral hypoglycemic [antidiabetic] drugs',
#  "Alzheimer's disease",
#  'Alcoholic hepatitis',
#  'Esophageal varices',
#  'Bipolar disorder',
#  'Hematuria',
#  'Glaucoma',
#  'Oral mucositis (ulcerative)',
#  'Fracture of mandible',
#  'Hyperaldosteronism',
#  'Basophilia',
#  'Nicotine dependence, unspecified',
#  'Keratitis',
#  'Cannabis use, unspecified with psychotic disorder',
#  'Migraine, unspecified, not intractable',
#  'Alcohol dependence with withdrawal',
#  'Laceration without foreign body of oral cavity',
#  'Pulmonary embolism',
#  'Adverse effect of anticoagulants',
#  'Epilepsy, unspecified',
#  'Periprosthetic fracture around internal prosthetic right knee joint, initial encounter',
#  'Other diseases of upper respiratory tract',
#  'Migraine',
#  'Peptic ulcer, site unspecified',
#  'Scoliosis',
#  'Radiculopathy',
#  'Severe persistent asthma',
#  'Nicotine dependence, cigarettes',
#  'Fluid overload',
#  'Other psychoactive substance use, unspecified',
#  'Inguinal hernia',
#  'Cryptococcosis',
#  'Malignant neoplasm of larynx',
#  'Hypertensive heart disease',
#  'Muscle spasm',
#  'Family history of osteoporosis',
#  'Personal history of malignant neoplasm of bronchus and lung',
#  'Ectopic pregnancy',
#  'Pemphigus vulgaris',
#  'Asphyxiation',
#  'Hemiplegia and hemiparesis following cerebral infarction affecting left dominant side',
#  'Poisoning by other antiepileptic and sedative-hypnotic drugs, intentional self-harm',
#  'Umbilical hernia',
#  'Personal history of malignant neoplasm of stomach',
#  'Acquired absence of pancreas',
#  'Calculus of bile duct without cholangitis or cholecystitis',
#  'Hodgkin lymphoma, unspecified',
#  'Personal history of malignant neoplasm of rectum, rectosigmoid junction, and anus',
#  'Alcohol abuse',
#  'Ulcerative colitis, unspecified',
#  'Volume depletion',
#  'Endometriosis',
#  'Nausea and vomiting',
#  'Personal history of malignant neoplasm of kidney',
#  'Respiratory failure, unspecified',
#  'Ventral hernia',
#  'Multiple myeloma',
#  'Erythema multiforme',
#  'Proteinuria',
#  'Epidural hemorrhage with loss of consciousness of unspecified duration',
#  'Other spondylosis with radiculopathy, thoracic region',
#  'Pelvic varices',
#  'Follicular lymphoma',
#  'Malignant neoplasm of breast',
#  'Hemiplegic migraine',
#  'Myeloid leukemia',
#  'Acute cystitis',
#  'Personal history of malignant neoplasm',
#  'Other abnormal findings in urine',
#  'Hydrocephalus',
#  'Acute appendicitis',
#  'Neutropenia',
#  'Mantle cell lymphoma',
#  'Tension-type headache',
#  'Gastritis, unspecified',
#  'Blastomycosis',
#  'Dacryoadenitis',
#  'Malignant neoplasm of bladder',
#  'Pulmonary edema',
#  'Vomiting',
#  'Vestibular neuronitis',
#  'Vascular dementia',
#  'Duodenal ulcer',
#  'Cocaine abuse',
#  'Thyroiditis',
#  'Ankylosing spondylitis',
#  'Violent behavior',
#  'Other specified disorders of bone density and structure',
#  'Allergy, unspecified',
#  'Gout',
#  'Personal history of malignant neoplasm of skin',
#  'Acute pancreatitis',
#  'Opioid dependence',
#  'Other stimulant use, unspecified',
#  'Sciatica',
#  'HELLP syndrome',
#  'Infection and inflammatory reaction due to internal right hip prosthesis',
#  'Unspecified dementia',
#  'Dorsalgia',
#  'Follicular lymphoma, unspecified',
#  'Spondylosis without myelopathy or radiculopathy',
#  'Type 2 diabetes mellitus',
#  'Severe sepsis',
#  'Viral pericarditis',
#  'Malignant neoplasm of ureter',
#  'Lactose intolerance',
#  'Cocaine use, unspecified',
#  'Traumatic subarachnoid hemorrhage with loss of consciousness of unspecified duration',
#  'Unspecified fracture of shaft of right tibia, initial encounter for closed fracture',
#  "Cushing's syndrome",
#  'Dyspnea',
#  'Ascites',
#  'Otorrhea',
#  'Nontraumatic subdural hemorrhage',
#  'Endometrial hyperplasia',
#  'Hypertensive retinopathy',
#  'Acute and chronic respiratory failure',
#  'Migraine, unspecified',
#  'Migraine without aura',
#  'Presence of artificial shoulder joint',
#  'Diffuse traumatic brain injury with loss of consciousness of unspecified duration',
#  'Stress fracture',
#  'Insomnia',
#  'Primary open-angle glaucoma',
#  'Fall on same level from slipping, tripping and stumbling without subsequent striking against object',
#  'Esophagitis',
#  'Schizophrenia',
#  'Cardiomyopathy',
#  'Candidiasis',
#  'Cystic fibrosis',
#  'Malignant neoplasm of ovary',
#  'Urticaria',
#  'Cyclical vomiting',
#  'Cystitis',
#  'Ulcerative colitis, unspecified, with complications',
#  'Chorioamnionitis, third trimester',
#  'Pressure ulcer of right elbow, stage 4',
#  'Chronic viral hepatitis',
#  'Retention of urine',
#  'Cerebral infarction',
#  'Cholecystitis',
#  'Cerebral infarction due to thrombosis of unspecified cerebral artery',
#  'Cytomegaloviral disease',
#  'Miliary tuberculosis',
#  'Adverse effect of glucocorticoids and synthetic analogues',
#  'Peritonitis',
#  'Cervical disc disorder with radiculopathy']

# %%
totalMissingTitles = [cod2desc[x] for x in totalMissingCodes]

# %%
totalMissingTitles
# Out:
# ['Overweight',
#  'Contusion of oral cavity, initial encounter',
#  'Ankylosis, left hip',
#  'Adverse effect of inhaled anesthetics, initial encounter',
#  'von Gierke disease',
#  'Cell of prison as the place of occurrence of the external cause',
#  'Garden or yard in single-family (private) house as the place of occurrence of the external cause',
#  'Underdosing of other antacids and anti-gastric-secretion drugs, initial encounter',
#  'Other abnormal findings in urine',
#  'Kitchen of single-family (private) house as the place of occurrence of the external cause',
#  'Underdosing of rifampicins, initial encounter',
#  'Blister (nonthermal), left lower leg, initial encounter',
#  'Abrasion of right forearm, initial encounter',
#  'Melanocytic nevi of trunk',
#  'Dependent relative needing care at home',
#  'Periprosthetic fracture around internal prosthetic right hip joint, initial encounter',
#  'Straining to void',
#  'Coma scale, best verbal response, confused conversation, at arrival to emergency department',
#  'Surgical instruments, materials and general- and plastic-surgery devices (including sutures) associated with adverse incidents',
#  'Fall from, out of or through other building or structure, initial encounter',
#  'Forest as the place of occurrence of the external cause',
#  'Supervision of elderly multigravida, first trimester',
#  'Cochlear implant status',
#  'Coma scale, best verbal response, confused conversation, at hospital admission',
#  'Family history of tobacco abuse and dependence',
#  'Malignant neoplasm of base of tongue',
#  'Congenital cerebral cysts',
#  'Coma scale, best motor response, obeys commands, 24 hours or more after hospital admission',
#  'Other specified disorders of teeth and supporting structures',
#  'Garden or yard of unspecified non-institutional (private) residence as the place of occurrence of the external cause',
#  'Activity, walking, marching and hiking',
#  'Other specified diseases of pancreas',
#  'Other specified events, undetermined intent, initial encounter',
#  'Ambulatory surgery center as the place of occurrence of the external cause',
#  'Perianal venous thrombosis',
#  'Abrasion, right thigh, initial encounter',
#  'Coma scale, best verbal response, incomprehensible words, at arrival to emergency department',
#  'Sprain of tibiofibular ligament of left ankle, initial encounter',
#  'Vitreous degeneration, bilateral',
#  'Leukoplakia of vulva',
#  'Activity, personal bathing and showering',
#  'Non-pressure chronic ulcer of right calf limited to breakdown of skin',
#  'Viral hepatitis complicating childbirth',
#  'Simple chronic bronchitis',
#  'Other microscopic hematuria',
#  'Bathroom in other specified residential institution as the place of occurrence of the external cause',
#  'Nonrheumatic tricuspid (valve) stenosis',
#  'Bathroom of single-family (private) house as the place of occurrence of the external cause',
#  'Dual role transvestism',
#  'Body mass index (BMI) 21.0-21.9, adult',
#  'Kitchen in apartment as the place of occurrence of the external cause',
#  'Congenital single renal cyst',
#  'Gastric diverticulum',
#  'Laceration without foreign body of left index finger without damage to nail, initial encounter',
#  'Blood alcohol level of 40-59 mg/100 ml',
#  'Localized swelling, mass and lump, right lower limb',
#  'Private driveway to single-family (private) house as the place of occurrence of the external cause',
#  'Bedroom of single-family (private) house as the place of occurrence of the external cause',
#  'NIHSS score 26',
#  'Immunization not carried out because of other contraindication',
#  "Patient's unintentional underdosing of medication regimen due to age-related debility",
#  'Unspecified mental disorder due to known physiological condition',
#  'Other right bundle-branch block',
#  'Periprosthetic fracture around internal prosthetic left hip joint, initial encounter',
#  'Other conduct disorders',
#  'Unspecified place in apartment as the place of occurrence of the external cause',
#  'Sequelae of poliomyelitis',
#  'Bursitis of left shoulder',
#  'Other hyperlipidemia',
#  'Bathroom in other non-institutional residence as the place of occurrence of the external cause',
#  'Maternal hypotension syndrome, third trimester',
#  'Person boarding or alighting a car injured in noncollision transport accident, initial encounter',
#  'Malignant neoplasm of gallbladder',
#  'Encounter for attention to cystostomy',
#  'Abnormal findings on diagnostic imaging of other specified body structures',
#  'Beach as the place of occurrence of the external cause',
#  'Obesity complicating pregnancy, first trimester',
#  'Non-pressure chronic ulcer of unspecified part of right lower leg limited to breakdown of skin',
#  'Kitchen of unspecified non-institutional (private) residence as the place of occurrence of the external cause',
#  'Contusion of left forearm, initial encounter',
#  'Body mass index (BMI) 25.0-25.9, adult',
#  'Abnormal finding of blood chemistry, unspecified',
#  'Private garage of single-family (private) house as the place of occurrence of the external cause',
#  'Cracked tooth',
#  'Bedroom in nursing home as the place of occurrence of the external cause',
#  'Short Achilles tendon (acquired), right ankle',
#  'Body mass index (BMI) 23.0-23.9, adult',
#  'Immunization not carried out because of patient refusal',
#  'Varus deformity, not elsewhere classified, right knee',
#  'Illiteracy and low-level literacy',
#  'Other specified public building as the place of occurrence of the external cause',
#  'Body mass index (BMI) 22.0-22.9, adult',
#  'Glasgow coma scale score 9-12, at arrival to emergency department',
#  'Contusion of right shoulder, initial encounter',
#  'Coma scale, eyes open, to sound, at hospital admission',
#  'Health care provider office as the place of occurrence of the external cause',
#  'Pallor',
#  'Motorcycle rider (driver) (passenger) injured in unspecified traffic accident, subsequent encounter',
#  'Body mass index (BMI) 20.0-20.9, adult',
#  'Human immunodeficiency virus [HIV] disease',
#  'Cholesterolosis of gallbladder',
#  'Fall from moving wheelchair (powered), initial encounter',
#  'Other difficulties with micturition',
#  'Walked into furniture, initial encounter',
#  'Bedroom in apartment as the place of occurrence of the external cause',
#  'Religious institution as the place of occurrence of the external cause',
#  'NIHSS score 13',
#  'Chronic apical periodontitis',
#  'Public park as the place of occurrence of the external cause',
#  'Labor and delivery complicated by cord around neck, with compression, not applicable or unspecified',
#  'Other secondary pulmonary hypertension',
#  'College as the place of occurrence of the external cause',
#  'Malposition of uterus',
#  'Other specified congenital malformations of intestine',
#  'Major osseous defect, left ankle and foot',
#  'Occupational exposure to environmental tobacco smoke',
#  'Unspecified residential institution as the place of occurrence of the external cause',
#  'Other specified disorders of eye and adnexa',
#  'Phakomatosis, unspecified',
#  'Other specified postprocedural states',
#  'Other uterine inertia',
#  'Periprosthetic fracture around internal prosthetic right knee joint, initial encounter',
#  'Complete loss of teeth, unspecified cause, unspecified class',
#  'Blood alcohol level of 100-119 mg/100 ml',
#  'Other cerebral infarction',
#  'Underdosing of other parasympatholytics [anticholinergics and antimuscarinics] and spasmolytics, initial encounter',
#  'Elevated prostate specific antigen [PSA]',
#  'Periprosthetic fracture around internal prosthetic left knee joint, initial encounter',
#  'Pressure ulcer of head, unstageable']

# %%
tot = list(cod2desc.keys())

# %%
def get_cousines(code):
    parent = cm.get_parent(code)
    grandpa = cm.get_parent(parent)
    cousines = [cm.get_children(x) for x in cm.get_children(grandpa) if x != parent]
    cousines = [item for sublist in cousines for item in sublist]
    cousines = [x for x in cousines if cm.is_leaf(x)]
    cousines = [x.replace(".", "") for x in cousines]
    random.shuffle(cousines)
    return cousines

# %%
import re

# %%
orderedCodes = []
with open(DATA_DIR + "2020order.txt", 'r') as f:
    for line in f:
        splitted = line.split()
        if splitted[2] == "1":
            orderedCodes.append(splitted[1])

# %%
def read_range(range):
    equivalentCodes = []
    splitted = range.split("-")
    splitted = [x.replace(" ", "") for x in splitted]
    if len(splitted) == 2 and len(splitted[0]) != 0 and len(splitted[1]) != 0:
        a = orderedCodes.index([x for x in orderedCodes if x.startswith(splitted[0].replace(".", ""))][0])
        b = orderedCodes.index([x for x in orderedCodes if x.startswith(splitted[1].replace(".", ""))][-1])
        equivalentCodes.extend(orderedCodes[a:b+1])
    return equivalentCodes

def read_family(family):
    equivalentCodes = []
    splitted = family.split("-")
    splitted = [x.replace(" ", "") for x in splitted]
    if len(splitted) == 2 and len(splitted[0]) != 0 and len(splitted[1]) == 0:
        equivalentCodes.extend([x.replace(".","") for x in cm.get_descendants(splitted[0].replace(".",""))])
    return [x.replace(".","") for x in equivalentCodes]

def read_code(code):
    splitted = code.split("-")
    splitted = [x.replace(" ", "") for x in splitted]
    equivalentCodes = []
    if len(splitted) == 1:
        descendant = [x.replace(".","") for x in cm.get_descendants(splitted[0].replace(".",""))]
        if len(descendant) > 0:
            equivalentCodes.extend(descendant)
        else:
            equivalentCodes.append(splitted[0].replace(".",""))
    return [x.replace(".","") for x in equivalentCodes]

def read_range_family_code(s):
    rangePattern = r"[A-Z][A-Z0-9]*(\.[A-Z0-9]+)?-[A-Z][A-Z0-9]*(\.[A-Z0-9]+)?"
    familyPattern = r"[A-Z][A-Z0-9]*(\.)?([A-Z0-9]+)?-"
    codePattern = r"^[^-]*$"
    equivalentCodes = []

    if re.match(rangePattern, s):
        equivalentCodes = read_range(s)
    elif re.match(familyPattern, s):
        equivalentCodes = read_family(s)
    elif re.match(codePattern, s):
        equivalentCodes = read_code(s)
    
    return [x.replace(".","") for x in equivalentCodes]
    


def read_with(w):
    equivalentCodes = []
    if "with" in w:
        splitted = w.split("with")
        prefixcodes = splitted[0].split(",")
        prefixcodes = [x.replace(" ", "") for x in prefixcodes]
        suffixcodes = splitted[1].split(",")
        suffixcodes = [x.replace(" ", "").replace(".", "") for x in suffixcodes]

        pre = []
        for p in prefixcodes:
            pre.extend(read_range_family_code(p))
        
        for p in pre:
            p2 = p[3:]
            for s in suffixcodes:
                if p2.startswith(s):
                    equivalentCodes.append(p)
    return [x.replace(".","") for x in equivalentCodes]


        
def get_excludes(code):
    equivalentCodes = []
    if cm.is_valid_item(code):
        negatives = set(cm.get_excludes1(code) + cm.get_excludes2(code))
        for c in negatives:
            if not cm.is_valid_item(c):
                if not c.endswith(")"):
                    continue
                else:
                    match = re.search(r'\(([^()]*)\)(?!.*\([^()]*\))',  c)
                    if match:
                        extracted_codes = [match.group(1)]
                    else:
                        extracted_codes = []
                    if len(extracted_codes) > 0:
                        extracted_code = extracted_codes[0]
                        if "with final characters" in extracted_code:
                            equivalentCodes.extend([])
                        if "with" in extracted_code:
                            equivalentCodes.extend(read_with(extracted_code))
                        else:
                            splitted = extracted_code.split(",")
                            splitted = [x.replace(" ", "") for x in splitted]
                            for s in splitted:
                                if s != "":
                                    equivalentCodes.extend(read_range_family_code(s))
            else:
                equivalentCodes.append(c.replace(".",""))
    return [x.replace(".","") for x in equivalentCodes]

# %%
cod2desc["U071"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_67992\3295644691.py in <module>
# ----> 1 cod2desc["U071"]
#
# KeyError: 'U071'

# %%
negatives = {}
for code in orderedCodes:
    neg = set()
    if cm.is_valid_item(code):
        if len(cm.get_excludes1(code) + cm.get_excludes2(code)) > 0:
            neg.update(get_excludes(code))
        neg.update(get_cousines(code))
    
    toups = []
    for n in neg:
        if n in cod2desc:
            toups.append((n, 0))
    
    random.shuffle(toups)
    #toups = [(cod2desc[x], 0) for x in neg if x in cod2desc] 
    negatives[code] = toups

# %%
# conta il numero medio di elementi per ogni lista di esclusi
total = 0
for k, v in negatives.items():
    total += len(v)
total /= len(negatives)
print("Average number of elements per list of excludes: ", total)

# conta quanti elementi hanno zero esclusi
total = 0
for k, v in negatives.items():
    if len(v) == 0:
        total += 1
print("Number of elements with zero excludes: ", total)
# Out:
# Average number of elements per list of excludes:  24.012772913665078
# Number of elements with zero excludes:  1718

# %%
neg = [("come", 1), ("ciao", 0), ("stai", 2)]
neg = sorted(neg, key=lambda x: x[1])
print(neg)
# Out:
# [('ciao', 0), ('come', 1), ('stai', 2)]

# %%
touples = []

for term, code in pairs:
    upperTerm = term.upper()
    neg = []
    hn = []
    rn = []
    if code in negatives:
        neg = negatives[code]
    if len(neg) > 0:
        neg = sorted(neg, key=lambda x: x[1])
        size = min(5, len(neg))
        i = 0
        while len(hn) < size and i < len(neg):
            if not upperTerm in cod2ents[neg[i][0]]:
                hn.append(neg[i])
                neg[i] = (neg[i][0], neg[i][1] + 1)
            i += 1
    negatives[code] = neg

    nrand = 10 - len(hn)
    while len(rn) < nrand:
        rand = random.choice(tot)
        if not upperTerm in cod2ents[rand]:
            rn.append((rand, 0))
    
    n = hn + rn
    touples.append((
            term, 
            cod2desc[code], 
            cod2desc[n[0][0]], 
            cod2desc[n[1][0]], 
            cod2desc[n[2][0]], 
            cod2desc[n[3][0]], 
            cod2desc[n[4][0]],
            cod2desc[n[5][0]],
            cod2desc[n[6][0]],
            cod2desc[n[7][0]],
            cod2desc[n[8][0]],
            cod2desc[n[9][0]]
        ))

# %%
touples
# Out:
# [('Anterior exenteration',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of left ureter',
#   'Malignant neoplasm of left renal pelvis',
#   'Malignant neoplasm of overlapping sites of urinary organs',
#   'Malignant neoplasm of urinary organ, unspecified',
#   'Malignant neoplasm of urethra',
#   'Nondisplaced fracture of head of right radius, initial encounter for open fracture type IIIA, IIIB, or IIIC',
#   'Other otitis externa, right ear',
#   'Unspecified injury of unspecified elbow, sequela',
#   'Displaced oblique fracture of shaft of unspecified tibia, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Toxic effect of tetrachloroethylene, intentional self-harm, initial encounter'),
#  ('Atorvastatin',
#   'Hyperlipidemia, unspecified',
#   'Hypovolemia',
#   'Classical phenylketonuria',
#   'Defects in post-translational modification of lysosomal enzymes',
#   'Cystic fibrosis with other manifestations',
#   'Organ-limited amyloidosis',
#   'Unspecified reduction defect of lower limb',
#   'Nondisplaced fracture of trapezoid [smaller multangular], unspecified wrist, initial encounter for open fracture',
#   'Other thyrotoxicosis without thyrotoxic crisis or storm',
#   'Terrorism involving explosion of marine weapons, public safety official injured, initial encounter',
#   'Fracture of unspecified carpal bone, right wrist, subsequent encounter for fracture with routine healing'),
#  ('Urostomy',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of paraurethral glands',
#   'Malignant neoplasm of unspecified renal pelvis',
#   'Malignant neoplasm of right renal pelvis',
#   'Malignant neoplasm of unspecified ureter',
#   'Malignant neoplasm of right kidney, except renal pelvis',
#   'Adverse effect of ophthalmological drugs and preparations, subsequent encounter',
#   'Other physeal fracture of upper end of left tibia, subsequent encounter for fracture with delayed healing',
#   'Nondisplaced fracture of unspecified radial styloid process, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Acute myeloid leukemia with multilineage dysplasia, not having achieved remission',
#   'Wilderness area'),
#  ('Bladder cancer',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of unspecified kidney, except renal pelvis',
#   'Malignant neoplasm of left kidney, except renal pelvis',
#   'Malignant neoplasm of right ureter',
#   'Malignant neoplasm of paraurethral glands',
#   'Malignant neoplasm of unspecified renal pelvis',
#   'Nondisplaced fracture of shaft of fourth metacarpal bone, right hand, sequela',
#   'Toxic effect of dichloromethane, intentional self-harm, sequela',
#   'Drug-induced chronic gout, wrist',
#   'Poisoning by antiallergic and antiemetic drugs, intentional self-harm, subsequent encounter',
#   'Unspecified injury of right external jugular vein'),
#  ('Losartan',
#   'Essential (primary) hypertension',
#   'Pre-existing hypertensive chronic kidney disease complicating childbirth',
#   'Cerebral infarction due to thrombosis of basilar artery',
#   'Occlusion and stenosis of right vertebral artery',
#   'Unspecified symptoms and signs involving cognitive functions following unspecified cerebrovascular disease',
#   'Occlusion and stenosis of unspecified precerebral artery',
#   'Salpingitis and oophoritis',
#   'Problems related to release from prison',
#   'Nondisplaced comminuted supracondylar fracture without intercondylar fracture of left humerus, initial encounter for closed fracture',
#   'Infestation, unspecified',
#   'Electrocution, initial encounter'),
#  ('Ileal conduit',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of unspecified kidney, except renal pelvis',
#   'Malignant neoplasm of left kidney, except renal pelvis',
#   'Malignant neoplasm of right ureter',
#   'Malignant neoplasm of right renal pelvis',
#   'Malignant neoplasm of unspecified ureter',
#   'Gastric contents in trachea causing asphyxiation, sequela',
#   'Blister (nonthermal) of throat, sequela',
#   'Displaced fracture of posterior wall of right acetabulum',
#   'Nondisplaced fracture of proximal phalanx of right middle finger, sequela',
#   'Idiopathic acute pancreatitis with uninfected necrosis'),
#  ('Urology',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of left ureter',
#   'Malignant neoplasm of left renal pelvis',
#   'Malignant neoplasm of overlapping sites of urinary organs',
#   'Malignant neoplasm of urinary organ, unspecified',
#   'Malignant neoplasm of unspecified kidney, except renal pelvis',
#   'Unspecified injury of renal blood vessel',
#   'Traumatic rupture of collateral ligament of left middle finger at metacarpophalangeal and interphalangeal joint',
#   'Toxic effect of venom of ants, intentional self-harm, initial encounter',
#   'Cardiac murmurs and other cardiac sounds',
#   'Persistent migraine aura with cerebral infarction'),
#  ('Follow-up appointments',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of right kidney, except renal pelvis',
#   'Malignant neoplasm of urethra',
#   'Malignant neoplasm of left ureter',
#   'Malignant neoplasm of left renal pelvis',
#   'Malignant neoplasm of overlapping sites of urinary organs',
#   'Opioid abuse with other opioid-induced disorder',
#   'Underdosing of unspecified narcotics',
#   'Paving stone degeneration of retina, bilateral',
#   'Unspecified amblyopia, right eye',
#   'Pyonephrosis'),
#  ('Hypertension',
#   'Essential (primary) hypertension',
#   'Dysphasia following cerebral infarction',
#   'Other paralytic syndrome following other cerebrovascular disease affecting left non-dominant side',
#   'HELLP syndrome (HELLP), unspecified trimester',
#   'Cerebral infarction due to thrombosis of bilateral middle cerebral arteries',
#   'Unspecified sequelae of nontraumatic subarachnoid hemorrhage',
#   'Toxic effect of petroleum products, assault',
#   'Other contact with shark, initial encounter',
#   'Other osteoporosis with current pathological fracture, right forearm, sequela',
#   'Car driver injured in collision with fixed or stationary object in nontraffic accident, subsequent encounter',
#   'Nondisplaced transverse fracture of left patella, initial encounter for open fracture type IIIA, IIIB, or IIIC'),
#  ('PE',
#   'Personal history of pulmonary embolism',
#   'External constriction of unspecified front wall of thorax, sequela',
#   'Partial traumatic transphalangeal amputation of right little finger, subsequent encounter',
#   'Poisoning by ophthalmological drugs and preparations, accidental (unintentional), initial encounter',
#   'Unspecified injury of muscle, fascia and tendon of triceps, unspecified arm, sequela',
#   'Contusion and laceration of right cerebrum without loss of consciousness, initial encounter',
#   'Blind loop syndrome, not elsewhere classified',
#   'Poisoning by, adverse effect of and underdosing of psychostimulants',
#   'Induration penis plastica',
#   'Vitreous hemorrhage',
#   'Non-follicular (diffuse) lymphoma, unspecified, lymph nodes of axilla and upper limb'),
#  ('Warfarin',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of bisphosphonates',
#   'Pleurisy',
#   'Other mechanical complication of cranial or spinal infusion catheter',
#   'Drug-induced aplastic anemia',
#   'Toxic effect of lead and its compounds, intentional self-harm',
#   'Sprain of unspecified parts of lumbar spine and pelvis, sequela'),
#  ('Enoxaparin',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of bisphosphonates',
#   'Subluxation of C0/C1 cervical vertebrae, initial encounter',
#   'Incomplete and partial hydatidiform mole',
#   'Other specified injury of left vertebral artery, initial encounter',
#   'Major laceration of unspecified external jugular vein, subsequent encounter',
#   'Abrasion of right middle finger, subsequent encounter'),
#  ('SLNB',
#   'Other surgical procedures as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Other medical procedures as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Cardiac catheterization as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Blood-sampling as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Kidney dialysis as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Radiological procedure and radiotherapy as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Chronic right heart failure',
#   'Vertebro-basilar artery syndrome',
#   'Other physeal fracture of lower end of left tibia, initial encounter for closed fracture',
#   'NIHSS score 39',
#   'Laceration without foreign body of unspecified lesser toe(s) without damage to nail, initial encounter'),
#  ('Atorvastatin',
#   'Hyperlipidemia, unspecified',
#   'Other hyperphenylalaninemias',
#   'Acidosis',
#   'Amyloidosis, unspecified',
#   'Lactose intolerance, unspecified',
#   'Lipid storage disorder, unspecified',
#   'Contusion and laceration of left cerebrum with loss of consciousness of 1 hour to 5 hours 59 minutes, initial encounter',
#   'Poisoning by antiallergic and antiemetic drugs, accidental (unintentional)',
#   'Nondisplaced intertrochanteric fracture of right femur, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with nonunion',
#   'Breakdown (mechanical) of cardiac electrode, sequela',
#   'Displaced fracture of olecranon process without intraarticular extension of right ulna, initial encounter for open fracture type IIIA, IIIB, or IIIC'),
#  ('ProAir HFA inhaler',
#   'Chronic obstructive pulmonary disease, unspecified',
#   'Emphysema, unspecified',
#   'Suberosis',
#   'Respiratory conditions due to other specified external agents',
#   'Unspecified respiratory condition due to chemicals, gases, fumes and vapors',
#   "Coalworker's pneumoconiosis",
#   'Partial traumatic amputation of right shoulder and upper arm, level unspecified, initial encounter',
#   'Primary open-angle glaucoma, unspecified eye, severe stage',
#   'Secondary osteoarthritis, right ankle and foot',
#   'Postprocedural hematoma of the spleen following other procedure',
#   'Fracture of alveolus of mandible, sequela'),
#  ('DVT',
#   'Personal history of pulmonary embolism',
#   'Atherosclerosis of nonautologous biological bypass graft(s) of the extremities with intermittent claudication, bilateral legs',
#   'Transient alteration of awareness',
#   'External constriction, right lesser toe(s), sequela',
#   'Injury of unspecified nerve at ankle and foot level, unspecified leg, subsequent encounter',
#   'Food in pharynx causing other injury, initial encounter',
#   'Other specified disorders of amniotic fluid and membranes, unspecified trimester, fetus 3',
#   'Struck by turtle, sequela',
#   'Nondisplaced fracture of body of left talus, subsequent encounter for fracture with malunion',
#   'Opioid dependence with opioid-induced psychotic disorder with hallucinations',
#   'Pathological fracture in neoplastic disease, hip, unspecified, sequela'),
#  ('Breast IDC Grade 3',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Displaced oblique fracture of shaft of humerus, left arm, initial encounter for closed fracture',
#   'Nondisplaced fracture of base of neck of right femur, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Tympanosclerosis, bilateral',
#   'Other injury of tail of pancreas, subsequent encounter',
#   'Age-related osteoporosis without current pathological fracture',
#   'Open bite of unspecified toe(s) with damage to nail, sequela',
#   'Malignant neoplasm of bladder neck'),
#  ('Trazodone',
#   'Major depressive disorder, single episode, unspecified',
#   'Major depressive disorder, recurrent, moderate',
#   'Bipolar disorder, current episode depressed, severe, with psychotic features',
#   'Bipolar disorder, current episode depressed, severe, without psychotic features',
#   'Manic episode, unspecified',
#   'Bipolar disorder, current episode manic severe with psychotic features',
#   'Localized adiposity',
#   'Toxic effect of formaldehyde, assault, sequela',
#   'Monoplegia of upper limb affecting left dominant side',
#   'Abrasion of right thumb',
#   'Pica of infancy and childhood'),
#  ('Nebulization',
#   'Chronic obstructive pulmonary disease, unspecified',
#   'Panlobular emphysema',
#   'Bronchiectasis with acute lower respiratory infection',
#   'Pneumonitis due to inhalation of food and vomit',
#   'Cannabinosis',
#   "Flax-dressers' disease",
#   'Puncture wound with foreign body of unspecified breast, initial encounter',
#   'Open bite of left lesser toe(s) without damage to nail, subsequent encounter',
#   'Blastic NK-cell lymphoma',
#   'Other psychoactive substance abuse with psychoactive substance-induced psychotic disorder with hallucinations',
#   'Laceration of unspecified blood vessel at lower leg level'),
#  ('COPD',
#   'Chronic obstructive pulmonary disease, unspecified',
#   'Bagassosis',
#   'Siderosis',
#   'Simple chronic bronchitis',
#   'Bronchitis and pneumonitis due to chemicals, gases, fumes and vapors',
#   'Other respiratory conditions due to chemicals, gases, fumes and vapors',
#   'Assault by pushing or placing victim in front of motor vehicle, initial encounter',
#   'Unspecified kyphosis',
#   'Displaced fracture of greater trochanter of left femur, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with malunion',
#   'Displaced fracture of proximal phalanx of left lesser toe(s), initial encounter for open fracture',
#   'Contracture, unspecified joint'),
#  ('OSA',
#   'Obstructive sleep apnea (adult) (pediatric)',
#   'Circadian rhythm sleep disorder, unspecified type',
#   'Circadian rhythm sleep disorder, jet lag type',
#   'Other hypersomnia',
#   'Circadian rhythm sleep disorder, advanced sleep phase type',
#   'Idiopathic hypersomnia without long sleep time',
#   'Anterior cord syndrome at C3 level of cervical spinal cord',
#   'Person injured while boarding or alighting from snowmobile',
#   'Legal intervention involving other sharp objects, law enforcement official injured',
#   'Burn of second degree of knee',
#   'Displaced fracture of neck of fifth metacarpal bone, left hand, initial encounter for closed fracture'),
#  ('Lumpectomy',
#   'Other surgical procedures as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Cardiac catheterization as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Blood-sampling as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Kidney dialysis as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Medical procedure, unspecified as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Shock therapy as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Underdosing of pyrazolone derivatives, sequela',
#   'Other secondary osteonecrosis, unspecified fibula',
#   'Underdosing of anticholinesterase agents',
#   'Other sprain of left foot, sequela',
#   'Displaced transverse fracture of shaft of left radius, subsequent encounter for closed fracture with malunion'),
#  ('Antiphospholipid antibody syndrome',
#   'Antiphospholipid syndrome',
#   'Lupus anticoagulant syndrome',
#   'Other primary thrombophilia',
#   'Raised antibody titer',
#   'Antiphospholipid antibody with hemorrhagic disorder',
#   'Prothrombin gene mutation',
#   'Failed or difficult intubation',
#   'Salter-Harris Type IV physeal fracture of left calcaneus, subsequent encounter for fracture with delayed healing',
#   'Displaced segmental fracture of shaft of left femur, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with malunion',
#   'Unspecified dislocation of left ulnohumeral joint, sequela',
#   'Poisoning by antidiarrheal drugs, accidental (unintentional), subsequent encounter'),
#  ('Omeprazole',
#   'Gastro-esophageal reflux disease without esophagitis',
#   'Acute peptic ulcer, site unspecified, with perforation',
#   'Acute gastric ulcer with both hemorrhage and perforation',
#   'Acute duodenal ulcer without hemorrhage or perforation',
#   'Diverticulum of esophagus, acquired',
#   'Perforation of esophagus',
#   'Passenger in pick-up truck or van injured in collision with pedal cycle in traffic accident, sequela',
#   'Laceration without foreign body of left forearm, sequela',
#   'Concussion with loss of consciousness of any duration with death due to other cause prior to regaining consciousness, initial encounter',
#   "Mushroom-worker's lung",
#   'Breakdown (mechanical) of cardiac electronic device'),
#  ('Breast cancer',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Other injury of intrinsic muscle, fascia and tendon of right middle finger at wrist and hand level, subsequent encounter',
#   'Superficial foreign body, right great toe, initial encounter',
#   'Infections of urethra in pregnancy, unspecified trimester',
#   'Displaced fracture of medial condyle of right tibia, subsequent encounter for closed fracture with nonunion',
#   'Complete placenta previa NOS or without hemorrhage, first trimester',
#   'Displaced segmental fracture of shaft of radius, right arm, subsequent encounter for closed fracture with malunion',
#   'Other injury of inferior mesenteric artery, sequela'),
#  ('Anticoagulation',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of bisphosphonates',
#   'Unspecified fracture of upper end of right tibia, subsequent encounter for open fracture type I or II with nonunion',
#   'Nondisplaced fracture of medial condyle of right tibia, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Poisoning by unspecified drugs, medicaments and biological substances, accidental (unintentional), subsequent encounter',
#   'Type I occipital condyle fracture, left side',
#   'Laceration with foreign body of other finger with damage to nail',
#   'Burn of first degree of lower back'),
#  ('Anticoagulation therapy',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of bisphosphonates',
#   'Sicca syndrome with other organ involvement',
#   'Other injury of muscle, fascia and tendon of other parts of biceps, left arm',
#   'Toxic effect of manganese and its compounds, undetermined',
#   'Other varicella complications',
#   'Rheumatoid vasculitis with rheumatoid arthritis of unspecified site'),
#  ('Depression',
#   'Major depressive disorder, single episode, unspecified',
#   'Other manic episodes',
#   'Manic episode in partial remission',
#   'Manic episode, severe with psychotic symptoms',
#   'Manic episode in full remission',
#   'Dysthymic disorder',
#   'Toxic effect of halogenated insecticides, accidental (unintentional), subsequent encounter',
#   'Person on outside of car injured in noncollision transport accident in traffic accident, subsequent encounter',
#   'Parasomnia, unspecified',
#   'Corrosion of left eyelid and periocular area, subsequent encounter',
#   'Chronic atrophic gastritis without bleeding'),
#  ('Hematoma',
#   'Postprocedural hematoma of skin and subcutaneous tissue following other procedure',
#   'Intraoperative hemorrhage and hematoma of skin and subcutaneous tissue complicating a dermatologic procedure',
#   'Intraoperative hemorrhage and hematoma of skin and subcutaneous tissue complicating other procedure',
#   'Other intraoperative complications of skin and subcutaneous tissue',
#   'Accidental puncture and laceration of skin and subcutaneous tissue during other procedure',
#   'Accidental puncture and laceration of skin and subcutaneous tissue during a dermatologic procedure',
#   'Twin pregnancy, monochorionic/monoamniotic, first trimester',
#   "Nondisplaced Maisonneuve's fracture of left leg, subsequent encounter for open fracture type I or II with malunion",
#   'Dislocation of interphalangeal joint of right great toe, sequela',
#   'War operations involving accidental detonation of onboard marine weapons, military personnel, initial encounter',
#   'Jumping or diving into other water striking water surface causing drowning and submersion, sequela'),
#  ('T2DM',
#   'Type 2 diabetes mellitus without complications',
#   'Drug or chemical induced diabetes mellitus without complications',
#   'Other specified diabetes mellitus without complications',
#   'Type 1 diabetes mellitus without complications',
#   'Drug or chemical induced diabetes mellitus with unspecified complications',
#   'Other specified diabetes mellitus with unspecified complications',
#   'Torsion of appendix epididymis',
#   'Poisoning by other primarily systemic and hematological agents, intentional self-harm',
#   'Complete traumatic amputation at elbow level, left arm, sequela',
#   'Cytomegaloviral pancreatitis',
#   'Dislocation of other parts of unspecified shoulder girdle, initial encounter'),
#  ('GERD',
#   'Gastro-esophageal reflux disease without esophagitis',
#   'Chronic or unspecified duodenal ulcer with perforation',
#   'Acute peptic ulcer, site unspecified, with perforation',
#   'Acute gastric ulcer with both hemorrhage and perforation',
#   'Acute duodenal ulcer without hemorrhage or perforation',
#   'Diverticulum of esophagus, acquired',
#   'Injury of trochlear nerve, left side',
#   'Salter-Harris Type III physeal fracture of unspecified metatarsal, initial encounter for open fracture',
#   'Acute epidemic hemorrhagic conjunctivitis (enteroviral)',
#   'Displaced avulsion fracture of left ischium, initial encounter for open fracture',
#   'Nondisplaced comminuted fracture of shaft of left fibula, subsequent encounter for open fracture type I or II with nonunion'),
#  ('Sertraline',
#   'Major depressive disorder, single episode, unspecified',
#   'Bipolar disorder, current episode depressed, severe, with psychotic features',
#   'Bipolar disorder, current episode depressed, severe, without psychotic features',
#   'Major depressive disorder, recurrent, mild',
#   'Bipolar disorder, current episode hypomanic',
#   'Other recurrent depressive disorders',
#   'Person on outside of three-wheeled motor vehicle injured in collision with car, pick-up truck or van in traffic accident, sequela',
#   'Displaced fracture of lateral cuneiform of left foot, subsequent encounter for fracture with malunion',
#   'Nondisplaced segmental fracture of shaft of humerus, unspecified arm, subsequent encounter for fracture with delayed healing',
#   'Other specified injuries of left lower leg, initial encounter',
#   'Salter-Harris Type IV physeal fracture of phalanx of right toe, subsequent encounter for fracture with nonunion'),
#  ('DVT prophylaxis',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of bisphosphonates',
#   'Conjunctival concretions, right eye',
#   'Corrosion of first degree of upper back, initial encounter',
#   'Unequal limb length (acquired), left humerus',
#   'Fracture of unspecified metatarsal bone(s)',
#   'War operations involving combat using blunt or piercing object, civilian',
#   'Unspecified injury of unspecified muscle, fascia and tendon at shoulder and upper arm level, right arm, initial encounter',
#   'Displaced fracture of cuboid bone of unspecified foot, subsequent encounter for fracture with nonunion'),
#  ('Lovenox',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of bisphosphonates',
#   'Maternal care for viable fetus in abdominal pregnancy, unspecified trimester, fetus 4',
#   'Laceration of extensor muscle, fascia and tendon of left thumb at wrist and hand level, sequela',
#   'Laceration of axillary artery, right side, subsequent encounter',
#   'Carcinoma in situ of soft palate',
#   'Burn of unspecified degree of left foot',
#   'Nondisplaced fracture (avulsion) of lateral epicondyle of unspecified humerus'),
#  ('Warfarin',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of bisphosphonates',
#   'Fall from motorized mobility scooter, initial encounter',
#   'Corrosion of third degree of left lower leg',
#   'Central subluxation and dislocation of hip',
#   'Strain of unspecified muscle and tendon at lower leg level',
#   'Dislocation of midcarpal joint of left wrist, initial encounter'),
#  ('Diverticulosis',
#   'Diverticulosis of intestine, part unspecified, without perforation or abscess without bleeding',
#   'Diverticulitis of small intestine without perforation or abscess without bleeding',
#   'Diverticulitis of small intestine with perforation and abscess without bleeding',
#   'Diverticulitis of intestine, part unspecified, with perforation and abscess with bleeding',
#   'Diverticulosis of both small and large intestine without perforation or abscess with bleeding',
#   'Diverticulosis of both small and large intestine without perforation or abscess without bleeding',
#   'Parasitic endophthalmitis, unspecified, right eye',
#   'Injury of other specified nerves of neck, subsequent encounter',
#   'Other specified disorders of nervous system in diseases classified elsewhere',
#   'Superficial foreign body of left wrist',
#   'Atherosclerosis of nonautologous biological bypass graft(s) of the extremities with rest pain'),
#  ('Lymph node biopsy',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Unspecified occupant of three-wheeled motor vehicle injured in collision with other nonmotor vehicle in nontraffic accident, sequela',
#   "Harada's disease, unspecified eye",
#   'Poisoning by other parasympathomimetics [cholinergics], undetermined, initial encounter',
#   'Unspecified fracture of unspecified forearm, subsequent encounter for closed fracture with malunion',
#   'Asphyxiation due to being trapped in a (discarded) refrigerator, intentional self-harm, sequela',
#   "Monteggia's fracture of left ulna, subsequent encounter for open fracture type I or II with malunion",
#   'Corrosions involving 70-79% of body surface with 40-49% third degree corrosion'),
#  ('Antiphospholipid antibody syndrome',
#   'Antiphospholipid syndrome',
#   'Lupus anticoagulant syndrome',
#   'Other primary thrombophilia',
#   'Activated protein C resistance',
#   'Raised antibody titer',
#   'Antiphospholipid antibody with hemorrhagic disorder',
#   'Passenger in three-wheeled motor vehicle injured in collision with car, pick-up truck or van in traffic accident, subsequent encounter',
#   'Maternal care for face, brow and chin presentation, other fetus',
#   'Wiskott-Aldrich syndrome',
#   'Burn of third degree of multiple right fingers (nail), including thumb, subsequent encounter',
#   'Toxic effect of harmful algae and algae toxins, accidental (unintentional)'),
#  ('Iron deficiency anemia',
#   'Iron deficiency anemia, unspecified',
#   'Vitamin B12 deficiency anemia due to intrinsic factor deficiency',
#   'Vitamin B12 deficiency anemia due to selective vitamin B12 malabsorption with proteinuria',
#   'Drug-induced folate deficiency anemia',
#   'Other megaloblastic anemias, not elsewhere classified',
#   'Other vitamin B12 deficiency anemias',
#   'Other displaced fracture of base of first metacarpal bone, left hand, subsequent encounter for fracture with nonunion',
#   'Other specified injury of plantar artery of right foot, subsequent encounter',
#   'Salter-Harris Type I physeal fracture of upper end of radius, right arm, initial encounter for closed fracture',
#   'Passenger in three-wheeled motor vehicle injured in collision with pedal cycle in nontraffic accident, sequela',
#   'Cystic meniscus, unspecified lateral meniscus, right knee'),
#  ('Breast cancer',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Burn of first degree of axilla',
#   'Atherosclerosis of nonautologous biological bypass graft(s) of the left leg with ulceration of unspecified site',
#   'Non-Hodgkin lymphoma, unspecified, lymph nodes of axilla and upper limb',
#   'Age-related osteoporosis with current pathological fracture, unspecified lower leg, subsequent encounter for fracture with routine healing',
#   'Other streptococcal arthritis, vertebrae',
#   'Cognitive communication deficit',
#   'Displaced spiral fracture of shaft of left femur, subsequent encounter for open fracture type I or II with nonunion'),
#  ('Iron studies',
#   'Iron deficiency anemia, unspecified',
#   'Transcobalamin II deficiency',
#   'Vitamin B12 deficiency anemia, unspecified',
#   'Other specified nutritional anemias',
#   'Dietary folate deficiency anemia',
#   'Scorbutic anemia',
#   'Migraine, unspecified, intractable',
#   'Other traumatic nondisplaced spondylolisthesis of sixth cervical vertebra, subsequent encounter for fracture with delayed healing',
#   'Retained (old) intraocular foreign body, magnetic, in other or multiple sites, left eye',
#   'Other maternal diseases classifiable elsewhere but complicating pregnancy, childbirth and the puerperium',
#   'Injury of unspecified iliac blood vessel(s), subsequent encounter'),
#  ('Vitamin D deficiency',
#   'Vitamin D deficiency, unspecified',
#   'Deficiency of other vitamins',
#   "Wernicke's encephalopathy",
#   'Vitamin A deficiency with corneal ulceration and xerosis',
#   'Thiamine deficiency, unspecified',
#   'Vitamin A deficiency with xerophthalmic scars of cornea',
#   'Poisoning by other drugs, medicaments and biological substances, assault, sequela',
#   'Spontaneous rupture of other tendons, left hand',
#   'Other specified injury of posterior tibial artery, unspecified leg, sequela',
#   'Nondisplaced transverse fracture of shaft of right femur, initial encounter for open fracture type IIIA, IIIB, or IIIC',
#   'Poisoning by unspecified fibrinolysis-affecting drugs, intentional self-harm, initial encounter'),
#  ('Antiphospholipid syndrome',
#   'Antiphospholipid syndrome',
#   'Activated protein C resistance',
#   'Prothrombin gene mutation',
#   'Hemorrhagic disorder due to extrinsic circulating anticoagulants',
#   'Antiphospholipid antibody with hemorrhagic disorder',
#   'Heat fatigue, transient',
#   'Unspecified superficial injury of left foot, initial encounter',
#   'Zoonotic bacterial disease, unspecified',
#   'Nondisplaced fracture of first metatarsal bone, left foot, subsequent encounter for fracture with nonunion',
#   'Postdysenteric arthropathy, left wrist',
#   'Subluxation of proximal interphalangeal joint of unspecified thumb, initial encounter'),
#  ('Vitamin D level',
#   'Vitamin D deficiency, unspecified',
#   'Magnesium deficiency',
#   'Chromium deficiency',
#   'Other manifestations of thiamine deficiency',
#   'Essential fatty acid [EFA] deficiency',
#   'Sequelae of other nutritional deficiencies',
#   'Burn of first degree of multiple sites of wrist and hand',
#   'Opioid use, unspecified with opioid-induced psychotic disorder with delusions',
#   'Contusion, laceration, and hemorrhage of brainstem with loss of consciousness of 31 minutes to 59 minutes',
#   'Poisoning by cardiac-stimulant glycosides and drugs of similar action, accidental (unintentional), initial encounter',
#   'Displaced apophyseal fracture of left femur, subsequent encounter for open fracture type I or II with routine healing'),
#  ('EGD',
#   'Gastro-esophageal reflux disease without esophagitis',
#   'Chronic or unspecified duodenal ulcer with perforation',
#   'Perforation of esophagus',
#   'Acute gastrojejunal ulcer with hemorrhage',
#   'Chronic or unspecified gastrojejunal ulcer with both hemorrhage and perforation',
#   'Chronic duodenal ulcer without hemorrhage or perforation',
#   'Puncture wound with foreign body of oral cavity, subsequent encounter',
#   'Nondisplaced fracture of lesser trochanter of unspecified femur, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with routine healing',
#   'Salter-Harris Type II physeal fracture of left calcaneus, initial encounter for closed fracture',
#   'Adverse effect of otorhinolaryngological drugs and preparations, initial encounter',
#   'Other spontaneous disruption of anterior cruciate ligament of knee'),
#  ('DVT/PE',
#   'Personal history of pulmonary embolism',
#   'Nondisplaced transverse fracture of shaft of right tibia, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with malunion',
#   'Family history of eye and ear disorders',
#   'Capsular glaucoma with pseudoexfoliation of lens, left eye, stage unspecified',
#   'Occlusion and stenosis of other precerebral arteries',
#   'Chronic embolism and thrombosis of other specified deep vein of right lower extremity',
#   'Nondisplaced oblique fracture of shaft of left radius, initial encounter for open fracture type I or II',
#   'Displaced comminuted fracture of shaft of left tibia, subsequent encounter for closed fracture with malunion',
#   'Other fracture of T11-T12 vertebra, initial encounter for open fracture',
#   'Underdosing of peripheral vasodilators',
#   'Nondisplaced fracture of shaft of fifth metacarpal bone, right hand, sequela'),
#  ('Ferric gluconate',
#   'Iron deficiency anemia, unspecified',
#   'Nutritional anemia, unspecified',
#   'Folate deficiency anemia, unspecified',
#   'Protein deficiency anemia',
#   'Other dietary vitamin B12 deficiency anemia',
#   'Other folate deficiency anemias',
#   'Pigmentary glaucoma, right eye, severe stage',
#   'Sensorineural hearing loss, unilateral, right ear, with restricted hearing on the contralateral side',
#   'Combined forms of age-related cataract, right eye',
#   'Chemical pneumonitis due to anesthesia',
#   'Coma scale, eyes open, to pain, at arrival to emergency department'),
#  ('PPI',
#   'Gastro-esophageal reflux disease without esophagitis',
#   'Achalasia of cardia',
#   'Acute peptic ulcer, site unspecified, with both hemorrhage and perforation',
#   'Chronic peptic ulcer, site unspecified, without hemorrhage or perforation',
#   'Fistula of stomach and duodenum',
#   'Eosinophilic esophagitis',
#   'Displaced fracture of fifth metatarsal bone, unspecified foot, subsequent encounter for fracture with delayed healing',
#   'Benign neoplasm of uterine tubes and ligaments',
#   'Unspecified fracture of lesser toe(s)',
#   'Other fracture of shaft of right tibia, subsequent encounter for closed fracture with malunion',
#   'Other acute pancreatitis'),
#  ('Hyperlipidemia',
#   'Hyperlipidemia, unspecified',
#   'Other hyperphenylalaninemias',
#   'Acidosis',
#   'Amyloidosis, unspecified',
#   'Lactose intolerance, unspecified',
#   'Lipid storage disorder, unspecified',
#   'Displaced transverse fracture of unspecified patella, subsequent encounter for open fracture type I or II with nonunion',
#   'Unspecified physeal fracture of upper end of radius, right arm, subsequent encounter for fracture with malunion',
#   'Aggressive periodontitis, localized, severe',
#   'Crushing injury of unspecified external genital organs, female',
#   'Marasmic kwashiorkor'),
#  ('COPD',
#   'Chronic obstructive pulmonary disease, unspecified',
#   'Pneumoconiosis due to other dust containing silica',
#   'Bagassosis',
#   'Siderosis',
#   'Simple chronic bronchitis',
#   'Bronchitis and pneumonitis due to chemicals, gases, fumes and vapors',
#   'Other injury of intrinsic muscle, fascia and tendon of left little finger at wrist and hand level',
#   'Metabolic acidemia in newborn first noted during labor',
#   'Unspecified accident to other private fixed-wing aircraft, injuring occupant, subsequent encounter',
#   'Bitten by goose',
#   'Poisoning by antihyperlipidemic and antiarteriosclerotic drugs, accidental (unintentional), initial encounter'),
#  ('Subtherapeutic INR',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of bisphosphonates',
#   'Other injury of pancreas',
#   'Laceration of greater saphenous vein at lower leg level, unspecified leg, subsequent encounter',
#   'Military operations involving other fires, conflagrations and hot substances',
#   'Nondisplaced fracture of body of unspecified calcaneus, initial encounter for open fracture',
#   'Postprocedural shock'),
#  ('DICLOFENAC GEL',
#   'Trochanteric bursitis, right hip',
#   'Other bursitis of hip, right hip',
#   'Prepatellar bursitis, right knee',
#   'Other soft tissue disorders related to use, overuse and pressure of unspecified site',
#   'Other soft tissue disorders related to use, overuse and pressure other site',
#   'Other bursitis of knee, unspecified knee',
#   'Corrosion of second degree of multiple sites of head, face, and neck, initial encounter',
#   'Adult forced sexual exploitation, confirmed, subsequent encounter',
#   'Acquired deformity of chest and rib',
#   'Sixth [abducent] nerve palsy, left eye',
#   'Unstable burst fracture of fourth thoracic vertebra'),
#  ('INR',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of bisphosphonates',
#   'Superficial frostbite of right wrist, subsequent encounter',
#   'Congenital dislocation of hip, bilateral',
#   'Toxic effect of unspecified snake venom, accidental (unintentional), initial encounter',
#   'Upper respiratory tract hypersensitivity reaction, site unspecified',
#   'Other thyrotoxicosis with thyrotoxic crisis or storm'),
#  ('Depression',
#   'Major depressive disorder, single episode, unspecified',
#   'Persistent mood [affective] disorder, unspecified',
#   'Other manic episodes',
#   'Manic episode in partial remission',
#   'Manic episode, severe with psychotic symptoms',
#   'Manic episode in full remission',
#   'Other intraarticular fracture of lower end of right radius, subsequent encounter for closed fracture with delayed healing',
#   'Osteonecrosis in diseases classified elsewhere, right lower leg',
#   'Unspecified injury of femoral vein at hip and thigh level, unspecified leg, subsequent encounter',
#   'Low-tension glaucoma, left eye, moderate stage',
#   'Congenital ichthyosis, unspecified'),
#  ('Right trochanteric bursitis',
#   'Trochanteric bursitis, right hip',
#   'Other bursitis of hip, right hip',
#   'Prepatellar bursitis, right knee',
#   'Other soft tissue disorders related to use, overuse and pressure of unspecified site',
#   'Other soft tissue disorders related to use, overuse and pressure other site',
#   'Other bursitis of knee, left knee',
#   'Traumatic vasospastic syndrome',
#   'Other disorders of binocular movement',
#   'Unspecified open wound of abdominal wall, right upper quadrant without penetration into peritoneal cavity',
#   'Other fracture of lower end of left femur, subsequent encounter for closed fracture with routine healing',
#   'Other specified injury of long flexor muscle, fascia and tendon of left thumb at wrist and hand level, sequela'),
#  ('BRCA1 gene mutation',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Displaced fracture of base of neck of left femur, subsequent encounter for closed fracture with nonunion',
#   'Drug or chemical induced diabetes mellitus with mild nonproliferative diabetic retinopathy without macular edema, right eye',
#   'Other mixed anxiety disorders',
#   'Poisoning by anticoagulants, accidental (unintentional), subsequent encounter',
#   'Puncture wound with foreign body of right ring finger with damage to nail, sequela',
#   'Adhesions due to foreign body accidentally left in body following heart catheterization',
#   'Displacement of other nervous system device, implant or graft'),
#  ('Malabsorption',
#   'Vitamin D deficiency, unspecified',
#   'Other specified nutritional deficiencies',
#   'Deficiency of vitamin K',
#   "Vitamin A deficiency with Bitot's spot and conjunctival xerosis",
#   'Deficiency of multiple nutrient elements',
#   'Vitamin deficiency, unspecified',
#   'Displaced fracture of middle phalanx of right index finger',
#   'Swimming pool (public) as the place of occurrence of the external cause',
#   'Candidiasis',
#   'Dislocation of right ankle joint, sequela',
#   'Other decreased white blood cell count'),
#  ('IV iron infusion',
#   'Iron deficiency anemia, unspecified',
#   'Nutritional anemia, unspecified',
#   'Folate deficiency anemia, unspecified',
#   'Protein deficiency anemia',
#   'Other dietary vitamin B12 deficiency anemia',
#   'Other folate deficiency anemias',
#   'Other fractures of lower leg',
#   'Atypical femoral fracture, unspecified, initial encounter for fracture',
#   'War operations occurring after cessation of hostilities',
#   'Other specified osteochondropathies multiple sites',
#   'Other injury of muscle, fascia and tendon of triceps, unspecified arm, sequela'),
#  ('Lupus anticoagulant',
#   'Antiphospholipid syndrome',
#   'Activated protein C resistance',
#   'Prothrombin gene mutation',
#   'Hemorrhagic disorder due to extrinsic circulating anticoagulants',
#   'Displaced fracture of coronoid process of left ulna, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Passenger in heavy transport vehicle injured in collision with fixed or stationary object in traffic accident, sequela',
#   'Salter-Harris Type I physeal fracture of left metatarsal, initial encounter for open fracture',
#   'Myositis ossificans traumatica, right hand',
#   'Military operations involving explosion of unspecified marine weapon, military personnel, subsequent encounter',
#   'Nondisplaced fracture of coronoid process of unspecified ulna, initial encounter for open fracture type I or II',
#   'Interstitial myositis, shoulder'),
#  ('Ferritin',
#   'Iron deficiency anemia, unspecified',
#   'Transcobalamin II deficiency',
#   'Vitamin B12 deficiency anemia, unspecified',
#   'Other specified nutritional anemias',
#   'Dietary folate deficiency anemia',
#   'Scorbutic anemia',
#   'Displaced transverse fracture of shaft of left radius, subsequent encounter for open fracture type I or II with routine healing',
#   'Other injury of flexor muscle, fascia and tendon of unspecified thumb at forearm level, sequela',
#   'Vitreomacular adhesion, bilateral',
#   'Glaucoma secondary to eye inflammation, right eye',
#   'Idiopathic chronic gout, unspecified knee, without tophus (tophi)'),
#  ('Sentinel lymph node biopsy',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Inhalant use, unspecified with intoxication with delirium',
#   'Traumatic rupture of right ear drum',
#   'Unspecified atherosclerosis of native arteries of extremities, right leg',
#   'Measles with intestinal complications',
#   'Parapsoriasis',
#   'Poisoning by mixed antiepileptics, intentional self-harm, sequela',
#   'Broken internal joint prosthesis, other site'),
#  ('OSA',
#   'Obstructive sleep apnea (adult) (pediatric)',
#   'Insomnia due to medical condition',
#   'Other sleep related movement disorders',
#   'REM sleep behavior disorder',
#   'Parasomnia in conditions classified elsewhere',
#   'Recurrent hypersomnia',
#   'Stress fracture, tibia and fibula',
#   'Retinal vasculitis, bilateral',
#   'Nondisplaced spiral fracture of shaft of ulna, left arm, initial encounter for open fracture type IIIA, IIIB, or IIIC',
#   'Pathological fracture in neoplastic disease, left hand, sequela',
#   'Displacement of internal fixation device of other bones, subsequent encounter'),
#  ('A1C',
#   'Type 2 diabetes mellitus without complications',
#   'Drug or chemical induced diabetes mellitus without complications',
#   'Other specified diabetes mellitus without complications',
#   'Diabetes mellitus due to underlying condition without complications',
#   'Diabetes mellitus due to underlying condition with unspecified complications',
#   'Type 1 diabetes mellitus with unspecified complications',
#   'Displaced fracture of coronoid process of unspecified ulna, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with routine healing',
#   'Blister (nonthermal), unspecified ankle, sequela',
#   'Displaced oblique fracture of shaft of right femur, subsequent encounter for open fracture type I or II with delayed healing',
#   'Displaced fracture of medial condyle of unspecified tibia, subsequent encounter for open fracture type I or II with delayed healing',
#   'Occupant of streetcar injured in collision with motor vehicle in traffic accident'),
#  ('Fatigue',
#   'Iron deficiency anemia, unspecified',
#   'Nutritional anemia, unspecified',
#   'Vitamin B12 deficiency anemia due to intrinsic factor deficiency',
#   'Vitamin B12 deficiency anemia due to selective vitamin B12 malabsorption with proteinuria',
#   'Drug-induced folate deficiency anemia',
#   'Other megaloblastic anemias, not elsewhere classified',
#   'Torus fracture of lower end of unspecified fibula, subsequent encounter for fracture with delayed healing',
#   'Salter-Harris Type I physeal fracture of unspecified calcaneus, subsequent encounter for fracture with malunion',
#   'Anterior subluxation of right radial head, initial encounter',
#   'Other fracture of shaft of tibia',
#   'Displaced fracture of proximal phalanx of unspecified thumb, initial encounter for open fracture'),
#  ('Vascular surgery',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of bisphosphonates',
#   'Pingueculitis, left eye',
#   'Nondisplaced fracture of middle phalanx of finger',
# ...
#   'Angina pectoris, unspecified',
#   'Adverse effect of enzymes, sequela',
#   'Dislocation of other parts of left shoulder girdle',
#   'Subluxation of distal radioulnar joint of left wrist',
#   'Displaced oblique fracture of shaft of right fibula, initial encounter for open fracture type IIIA, IIIB, or IIIC',
#   'Displaced supracondylar fracture without intracondylar extension of lower end of right femur, sequela',
#   'Other specified injury of lesser saphenous vein at lower leg level, left leg, initial encounter',
#   'Injury of digital nerve of left thumb, sequela',
#   'Disseminated sporotrichosis',
#   'Complex tear of lateral meniscus, current injury, unspecified knee, subsequent encounter'),
#  ('Rosuvastatin',
#   'Hyperlipidemia, unspecified',
#   'Other lactose intolerance',
#   'Other disorders of glycoprotein metabolism',
#   'Porphyria cutanea tarda',
#   'Myoadenylate deaminase deficiency',
#   'Disorder of glycoprotein metabolism, unspecified',
#   'Car occupant injured in other and unspecified transport accidents',
#   'Toxic effect of corrosive acids and acid-like substances, assault, sequela',
#   'Heat exposure on board merchant ship, sequela',
#   'Nondisplaced segmental fracture of shaft of unspecified fibula, initial encounter for closed fracture',
#   'Nondisplaced spiral fracture of shaft of left fibula, subsequent encounter for open fracture type I or II with delayed healing'),
#  ('Cardiac surgery',
#   'Presence of aortocoronary bypass graft',
#   'Presence of spectacles and contact lenses',
#   'Allergy status to other drugs, medicaments and biological substances status',
#   'Family history of malignant neoplasm of other respiratory and intrathoracic organs',
#   'Presence of tooth-root and mandibular implants',
#   'Other artificial opening status',
#   'Unspecified fracture of the lower end of left radius, subsequent encounter for closed fracture with routine healing',
#   'Exposure to sudden change in air pressure in aircraft during ascent',
#   'Unspecified fracture of second thoracic vertebra',
#   'Accidental discharge from other specified firearms, sequela',
#   'Unspecified injury of flexor muscle, fascia and tendon of right little finger at wrist and hand level, sequela'),
#  ('Troponin',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Angina pectoris, unspecified',
#   'Major laceration of tail of pancreas',
#   'Other reactive arthropathies, multiple sites',
#   'Ulcerative colitis, unspecified with fistula',
#   'Toxic effect of contact with Portugese Man-o-war, intentional self-harm, initial encounter',
#   'Unspecified injury of left thigh',
#   'Strain of intrinsic muscle, fascia and tendon of right index finger at wrist and hand level',
#   'Salter-Harris Type IV physeal fracture of lower end of ulna, unspecified arm, subsequent encounter for fracture with routine healing',
#   'Military operations involving explosion of torpedo, military personnel, initial encounter',
#   'Pregnancy related exhaustion and fatigue, third trimester'),
#  ('Ranitidine',
#   'Gastro-esophageal reflux disease without esophagitis',
#   'Achalasia of cardia',
#   'Acute peptic ulcer, site unspecified, with both hemorrhage and perforation',
#   'Chronic peptic ulcer, site unspecified, without hemorrhage or perforation',
#   'Fistula of stomach and duodenum',
#   'Eosinophilic esophagitis',
#   'Person on outside of car injured in collision with pedal cycle in nontraffic accident, initial encounter',
#   'Laceration with foreign body of left back wall of thorax with penetration into thoracic cavity, subsequent encounter',
#   'Legal intervention involving injury by rifle pellet, unspecified person injured',
#   'Pingueculitis, right eye',
#   'Poisoning by coronary vasodilators, accidental (unintentional)'),
#  ('LAD',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Angina pectoris, unspecified',
#   'Drowning and submersion in natural water, undetermined intent',
#   'Other foreign object in pharynx causing asphyxiation, initial encounter',
#   'Squamous cell carcinoma of skin, unspecified',
#   'Driver injured in collision with other motor vehicles in nontraffic accident, subsequent encounter',
#   'Assault by hot fluids, sequela',
#   'Legal intervention involving injury by tear gas, unspecified person injured, subsequent encounter',
#   'Multiple fractures of ribs, left side, subsequent encounter for fracture with nonunion',
#   'Encounter for routine checking of intrauterine contraceptive device',
#   'Sprain of other specified parts of shoulder girdle'),
#  ('Fixed perfusion defect',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Angina pectoris, unspecified',
#   'Toxic effect of taipan venom, intentional self-harm, initial encounter',
#   'Malignant neoplasm of parotid gland',
#   'Unspecified disorder of vestibular function, left ear',
#   'Other nondisplaced fracture of third cervical vertebra, initial encounter for closed fracture',
#   'NIHSS score 6',
#   'Conjunctival concretions, unspecified eye',
#   'Other central nervous system complications of anesthesia during pregnancy',
#   'Poisoning by smallpox vaccines, assault',
#   'Nondisplaced fracture of fifth metatarsal bone, left foot, subsequent encounter for fracture with routine healing'),
#  ('Elevated left ventricular filling pressure',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Angina pectoris, unspecified',
#   'Breakdown (mechanical) of other urinary catheter, subsequent encounter',
#   'Other embolism in pregnancy',
#   'Unspecified fracture of first thoracic vertebra',
#   'Torus fracture of upper end of left humerus, initial encounter for closed fracture',
#   'Unspecified fracture of upper end of right humerus, subsequent encounter for fracture with malunion',
#   'Continuing pregnancy after elective fetal reduction of one fetus or more, third trimester',
#   'Infection and inflammatory reaction due to implanted electronic neurostimulator of brain, electrode (lead), subsequent encounter',
#   'Insect bite (nonvenomous) of unspecified shoulder, subsequent encounter',
#   'Pain in shoulder'),
#  ('Aspirin',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Dental caries on smooth surface penetrating into dentin',
#   'Passenger in three-wheeled motor vehicle injured in collision with pedal cycle in nontraffic accident',
#   'Other cardiac complications of anesthesia during pregnancy, third trimester',
#   'Toxic effect of carbon monoxide from incomplete combustion of other domestic fuels, intentional self-harm, subsequent encounter',
#   'Evidence of alcohol involvement determined by blood alcohol level',
#   'Jumping or diving into swimming pool striking bottom causing drowning and submersion, sequela',
#   'Displaced transverse fracture of shaft of right femur, subsequent encounter for open fracture type I or II with delayed healing',
#   'Other specified crystal arthropathies, right hand',
#   'Displaced spiral fracture of shaft of right tibia, subsequent encounter for open fracture type I or II with malunion',
#   'Occupant of aircraft injured in other specified air transport accidents'),
#  ('Ramus Mid Left Cx',
#   'Presence of coronary angioplasty implant and graft',
#   'Family history of other malignant neoplasms of lymphoid, hematopoietic and related tissues',
#   'Allergy status to analgesic agent status',
#   'Family history of malignant neoplasm, unspecified',
#   'Personal history of malignant neoplasm of breast',
#   'Family history of other mental and behavioral disorders',
#   'Low weight gain in pregnancy',
#   'Unspecified retinal break, left eye',
#   'Ainhum',
#   'Maternal hypotension syndrome',
#   'Sparganosis'),
#  ('CAD',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Angina pectoris, unspecified',
#   'Car driver injured in collision with pick-up truck in nontraffic accident',
#   'Angina pectoris, unspecified',
#   'Nondisplaced fracture of olecranon process with intraarticular extension of left ulna, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Corrosion of first degree of left thigh',
#   'Disruption of wound, not elsewhere classified',
#   'Laceration of unspecified muscles, fascia and tendons at forearm level, unspecified arm, initial encounter',
#   'Displaced fracture (avulsion) of medial epicondyle of right humerus, subsequent encounter for fracture with delayed healing',
#   'Inferior dislocation of left acromioclavicular joint, subsequent encounter',
#   'Legal intervention involving injury by tear gas, bystander injured, subsequent encounter'),
#  ('Metoprolol',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Angina pectoris, unspecified',
#   'Laceration with foreign body of trachea, subsequent encounter',
#   'Unspecified disorder of psychological development',
#   'Displaced fracture of body of left talus, initial encounter for open fracture',
#   'Calculus of bile duct with cholangitis, unspecified, with obstruction',
#   'Unspecified injury of bronchus, unilateral',
#   'Displaced comminuted fracture of shaft of left tibia, subsequent encounter for open fracture type I or II with delayed healing',
#   'Struck by hit or thrown ball, unspecified type, subsequent encounter',
#   'Alcoholic hepatitis with ascites',
#   'Sprain of other parts of lumbar spine and pelvis, initial encounter'),
#  ('Nitroglycerin',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Angina pectoris, unspecified',
#   'Military operation involving nuclear radiation effects of nuclear weapon, military personnel',
#   'Contusion of unspecified part of small intestine',
#   'Injury of unspecified nerve at shoulder and upper arm level, unspecified arm, initial encounter',
#   'Arthropathies in other specified diseases classified elsewhere, right wrist',
#   'Nondisplaced transverse fracture of shaft of unspecified femur, subsequent encounter for open fracture type I or II with routine healing',
#   'Displaced fracture of proximal phalanx of left little finger, sequela',
#   'Other infective (teno)synovitis, elbow',
#   'Laceration of unspecified blood vessel at hip and thigh level, left leg',
#   'Nondisplaced bicondylar fracture of left tibia, subsequent encounter for open fracture type I or II with delayed healing'),
#  ('BiV ICD',
#   'Encounter for adjustment and management of automatic implantable cardiac defibrillator',
#   'Encounter for adjustment or removal of myringotomy device (stent) (tube)',
#   'Encounter for adjustment and management of other implanted nervous system device',
#   'Encounter for adjustment and management of other implanted devices',
#   'Encounter for adjustment and management of neurostimulator',
#   'Encounter for adjustment and management of cerebrospinal fluid drainage device',
#   'Unspecified keratitis',
#   'Albinism, unspecified',
#   'Ankylosis, right shoulder',
#   "Melkersson's syndrome",
#   'Labor and delivery complicated by other cord complications'),
#  ('Respiratory acidosis',
#   'Mixed disorder of acid-base balance',
#   'Disorder of glycoprotein metabolism, unspecified',
#   'Organ-limited amyloidosis',
#   'Glucosaminoglycan metabolism disorder, unspecified',
#   'Hyperlipidemia, unspecified',
#   'Tumor lysis syndrome',
#   'Unspecified occupant of pick-up truck or van injured in collision with unspecified motor vehicles in nontraffic accident, sequela',
#   'Hypotension',
#   'Nondisplaced transverse fracture of shaft of right femur',
#   'Other fracture of shaft of right tibia, sequela',
#   'Gestational edema with proteinuria, first trimester'),
#  ('Schizophrenia',
#   'Paranoid schizophrenia',
#   'Schizoaffective disorder, bipolar type',
#   'Schizoaffective disorder, depressive type',
#   'Other schizoaffective disorders',
#   'Nondisplaced fracture of distal phalanx of left index finger, subsequent encounter for fracture with nonunion',
#   'Contact with other hot household appliances, subsequent encounter',
#   'Other injury of other muscle(s) and tendon(s) of posterior muscle group at lower leg level, unspecified leg, sequela',
#   'Unspecified speech disturbances',
#   'Other rupture of muscle (nontraumatic), left shoulder',
#   'Passenger on bus injured in noncollision transport accident in traffic accident, subsequent encounter',
#   'Displaced transverse fracture of shaft of right ulna, subsequent encounter for closed fracture with malunion'),
#  ('Hyperlipidemia',
#   'Hyperlipidemia, unspecified',
#   'Neuropathic heredofamilial amyloidosis',
#   'Crigler-Najjar syndrome',
#   'Hypokalemia',
#   'Disorder of aromatic amino-acid metabolism, unspecified',
#   'Disorders of zinc metabolism',
#   'Burn of first degree of left toe(s) (nail), sequela',
#   'Displaced supracondylar fracture without intracondylar extension of lower end of left femur',
#   'Salter-Harris Type III physeal fracture of upper end of radius, unspecified arm, initial encounter for closed fracture',
#   'Isolated proteinuria with minor glomerular abnormality',
#   'Nondisplaced comminuted fracture of shaft of unspecified femur, subsequent encounter for closed fracture with nonunion'),
#  ('Renal cancer',
#   'Personal history of other malignant neoplasm of kidney',
#   'Laceration of other muscle(s) and tendon(s) at lower leg level, unspecified leg, initial encounter',
#   'Unspecified intracranial injury with loss of consciousness greater than 24 hours with return to pre-existing conscious level',
#   'Squamous cell carcinoma of skin of left upper limb, including shoulder',
#   'Lead-induced gout, right shoulder',
#   'Salter-Harris Type I physeal fracture of upper end of right fibula, subsequent encounter for fracture with malunion',
#   'Contusion of descending [left] colon, initial encounter',
#   'Other specified injury of internal jugular vein',
#   'Other fracture of right patella, subsequent encounter for closed fracture with malunion',
#   'Unspecified injury of right renal vein, subsequent encounter',
#   'Displaced spiral fracture of shaft of left femur, subsequent encounter for closed fracture with nonunion'),
#  ('Hypoxia',
#   'Acute respiratory failure with hypoxia',
#   'Acute and chronic respiratory failure, unspecified whether with hypoxia or hypercapnia',
#   'Chronic respiratory failure, unspecified whether with hypoxia or hypercapnia',
#   'Chronic respiratory failure with hypercapnia',
#   'Toxic effect of contact with other venomous plant, undetermined, subsequent encounter',
#   'Unspecified fracture of T9-T10 vertebra, subsequent encounter for fracture with nonunion',
#   'Diffuse cystic mastopathy of right breast',
#   'Burn of third degree of left upper arm, initial encounter',
#   'Neoplasm of uncertain behavior of lymphoid, hematopoietic and related tissue, unspecified',
#   'Open bite of lower back and pelvis with penetration into retroperitoneum',
#   'Rheumatoid myopathy with rheumatoid arthritis of right hand'),
#  ('Metabolic acidosis',
#   'Mixed disorder of acid-base balance',
#   'Gilbert syndrome',
#   'Disorders of ornithine metabolism',
#   'Mucopolysaccharidosis, unspecified',
#   'Lesch-Nyhan syndrome',
#   'Disorder of amino-acid metabolism, unspecified',
#   'Minor laceration of external jugular vein',
#   'Age-related nuclear cataract, unspecified eye',
#   'Other and unspecified edema specific to newborn',
#   'Encounter for screening for depression',
#   'Plica syndrome, right knee'),
#  ('Hypotension',
#   'Cardiogenic shock',
#   'Polydipsia',
#   'Enlarged lymph nodes, unspecified',
#   'Fever, unspecified',
#   'Feeding difficulties',
#   'Weakness',
#   'Pain due to cardiac prosthetic devices, implants and grafts',
#   'Displaced associated transverse-posterior fracture of unspecified acetabulum, subsequent encounter for fracture with delayed healing',
#   'External constriction of left elbow, sequela',
#   'Dislocation of proximal interphalangeal joint of left ring finger, sequela',
#   'Drug or chemical induced diabetes mellitus with kidney complications'),
#  ...]

# %%
touples = []
for term, code in pairs:
    upperTerm = term.upper()
    if cm.is_valid_item(code):
        similars = [x for x in cm.get_excludes1(code) + cm.get_excludes2(code) + get_cousines(code) if x.replace(".", "") != code and cm.is_valid_item(x) and cm.is_leaf(x)]
        hardNegatives = [x for x in similars if x.replace(".", "") in cod2ents and upperTerm not in cod2ents[x.replace(".", "")]]
        hardNegatives = [x.replace(".", "") for x in hardNegatives][:5]

        numDistractors = 10 - len(hardNegatives)
        distractors = []
        while len(distractors) < numDistractors:
            distractors = [x for x in random.sample(tot, numDistractors) if x != code and x not in hardNegatives]
            distractors = [x for x in distractors if x.replace(".", "") in cod2ents and upperTerm not in cod2ents[x.replace(".", "")]]
        hardNegatives += distractors
        touples.append((
            term, 
            cod2desc[code], 
            cod2desc[hardNegatives[0]], 
            cod2desc[hardNegatives[1]], 
            cod2desc[hardNegatives[2]], 
            cod2desc[hardNegatives[3]], 
            cod2desc[hardNegatives[4]],
            cod2desc[hardNegatives[5]],
            cod2desc[hardNegatives[6]],
            cod2desc[hardNegatives[7]],
            cod2desc[hardNegatives[8]],
            cod2desc[hardNegatives[9]]
            ))

# %%
prova = random.sample(touples, 1)
for term, code, neg1, neg2, neg3, neg4, neg5, neg6, neg7, neg8, neg9, neg10 in prova:
    print(term)
    print(code)
    print(neg1)
    print(neg2)
    print(neg3)
    print(neg4)
    print(neg5)
    print(neg6)
    print(neg7)
    print(neg8)
    print(neg9)
    print(neg10)
    print()
# Out:
# Ileal loop
# Fistula of intestine
# Hemorrhage of anus and rectum
# Inflammatory polyps of colon with fistula
# Chronic vascular disorders of intestine
# Volvulus
# Rectal prolapse
# Chronic embolism and thrombosis of unspecified vein
# Unspecified fracture of lower end of right femur, subsequent encounter for closed fracture with routine healing
# Poisoning by unspecified drugs, medicaments and biological substances, undetermined, initial encounter
# Heat exposure on board other powered watercraft, initial encounter
# Toxic effect of unspecified inorganic substance, accidental (unintentional)

# %%
# prendi 200 tuple casuali dalla lista e crea una stringa formattata come un file di testo nel quale in ogni riga si ha: anchor: tupla[0], positive: tupla[1], negative1: tupla[2], negative2: tupla[3], negative3: tupla[4], negative4: tupla[5], negative5: tupla[6]


touples = random.sample(touples, 200)
with open(OUTPUT_DIR + "triplets.txt", 'w') as f:
    for t in touples:
        f.write(f"anchor: {t[0]}, positive: {t[1]}, negative1: {t[2]}, negative2: {t[3]}, negative3: {t[4]}, negative4: {t[5]}, negative5: {t[6]}\n")
# Out:
# [('Anterior exenteration',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of right kidney, except renal pelvis',
#   'Malignant neoplasm of left kidney, except renal pelvis',
#   'Malignant neoplasm of unspecified kidney, except renal pelvis',
#   'Malignant neoplasm of right renal pelvis',
#   'Malignant neoplasm of left renal pelvis',
#   'Cytomegaloviral pancreatitis',
#   'Chronic gout due to renal impairment, right knee, with tophus (tophi)',
#   'Blister (nonthermal) of right front wall of thorax, sequela',
#   'Toxic reaction to local anesthesia during pregnancy, third trimester',
#   'Unspecified car occupant injured in collision with sport utility vehicle in nontraffic accident, subsequent encounter'),
#  ('Atorvastatin',
#   'Hyperlipidemia, unspecified',
#   'Classical phenylketonuria',
#   'Other hyperphenylalaninemias',
#   'Disorders of tryptophan metabolism',
#   'Disorder of aromatic amino-acid metabolism, unspecified',
#   'Maple-syrup-urine disease',
#   'Adverse effect of thrombolytic drugs, initial encounter',
#   'Other somatoform disorders',
#   'Bitten by crocodile, sequela',
#   'Chronic postrheumatic arthropathy [Jaccoud], left wrist',
#   'Toxic effect of unspecified seafood, undetermined'),
#  ('Urostomy',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of right kidney, except renal pelvis',
#   'Malignant neoplasm of left kidney, except renal pelvis',
#   'Malignant neoplasm of unspecified kidney, except renal pelvis',
#   'Malignant neoplasm of right renal pelvis',
#   'Malignant neoplasm of left renal pelvis',
#   'Injury of unspecified nerve at forearm level, unspecified arm, sequela',
#   'Transient acantholytic dermatosis [Grover]',
#   'Other injury of extensor muscle, fascia and tendon of right ring finger at forearm level, initial encounter',
#   'Malignant neoplasm of connective and soft tissue of upper limb, including shoulder',
#   'Contusion of unspecified external genital organ, male, initial encounter'),
#  ('Bladder cancer',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of right kidney, except renal pelvis',
#   'Malignant neoplasm of left kidney, except renal pelvis',
#   'Malignant neoplasm of unspecified kidney, except renal pelvis',
#   'Malignant neoplasm of right renal pelvis',
#   'Malignant neoplasm of left renal pelvis',
#   'Other ossification of muscle, unspecified forearm',
#   'Other lack of coordination',
#   'Follicular lymphoma grade I, lymph nodes of inguinal region and lower limb',
#   'Person injured in collision between car and pick-up truck or van (traffic), initial encounter',
#   'Injury of unspecified nerve at lower leg level, unspecified leg, subsequent encounter'),
#  ('Losartan',
#   'Essential (primary) hypertension',
#   'Rheumatic fever without heart involvement',
#   'Pericarditis in diseases classified elsewhere',
#   'Endocarditis, valve unspecified',
#   'Endocarditis and heart valve disorders in diseases classified elsewhere',
#   'Myocarditis in diseases classified elsewhere',
#   'Person on outside of bus injured in collision with railway train or railway vehicle in nontraffic accident, sequela',
#   'Dislocation of T10/T11 thoracic vertebra, subsequent encounter',
#   'Passenger in pick-up truck or van injured in collision with pedal cycle in nontraffic accident, subsequent encounter',
#   'Drowning and submersion due to falling or jumping from other burning powered watercraft, sequela',
#   'Other amebic genitourinary infections'),
#  ('Ileal conduit',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of right kidney, except renal pelvis',
#   'Malignant neoplasm of left kidney, except renal pelvis',
#   'Malignant neoplasm of unspecified kidney, except renal pelvis',
#   'Malignant neoplasm of right renal pelvis',
#   'Malignant neoplasm of left renal pelvis',
#   'Nondisplaced fracture of third metatarsal bone, right foot, subsequent encounter for fracture with routine healing',
#   'Toxic effects of lead and its compounds',
#   'Labor and delivery complicated by other cord entanglement, with compression, fetus 2',
#   'Superficial foreign body of right thumb, initial encounter',
#   'Acquired atrophy of ovary, unspecified side'),
#  ('Urology',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of unspecified kidney, except renal pelvis',
#   'Malignant neoplasm of right renal pelvis',
#   'Malignant neoplasm of left renal pelvis',
#   'Malignant neoplasm of unspecified renal pelvis',
#   'Malignant neoplasm of right ureter',
#   'Nondisplaced fracture of glenoid cavity of scapula, right shoulder, initial encounter for closed fracture',
#   'Pedestrian with other conveyance injured in collision with heavy transport vehicle or bus in nontraffic accident, initial encounter',
#   'Activity, other specified',
#   'Nondisplaced transverse fracture of shaft of unspecified radius, subsequent encounter for open fracture type I or II with malunion',
#   'Salter-Harris Type IV physeal fracture of lower end of humerus, right arm, subsequent encounter for fracture with nonunion'),
#  ('Follow-up appointments',
#   'Malignant neoplasm of bladder neck',
#   'Malignant neoplasm of right kidney, except renal pelvis',
#   'Malignant neoplasm of left kidney, except renal pelvis',
#   'Malignant neoplasm of unspecified kidney, except renal pelvis',
#   'Malignant neoplasm of right renal pelvis',
#   'Malignant neoplasm of left renal pelvis',
#   'Congenital dilation of aorta',
#   'Pure motor lacunar syndrome',
#   'Acute lymphangitis of left axilla',
#   'Laceration of flexor muscle, fascia and tendon of left middle finger at wrist and hand level, initial encounter',
#   'Subacute osteomyelitis, femur'),
#  ('Hypertension',
#   'Essential (primary) hypertension',
#   'Rheumatic fever without heart involvement',
#   'Pericarditis in diseases classified elsewhere',
#   'Endocarditis, valve unspecified',
#   'Endocarditis and heart valve disorders in diseases classified elsewhere',
#   'Myocarditis in diseases classified elsewhere',
#   'Toxic effect of venom of bees, undetermined, sequela',
#   'Unspecified entropion of left eye, unspecified eyelid',
#   'Hydronephrosis with renal and ureteral calculous obstruction',
#   'Civilian aircraft involved in air transport accident with military aircraft, sequela',
#   'Pneumococcal arthritis, right hand'),
#  ('PE',
#   'Personal history of pulmonary embolism',
#   'Exposure to other nonionizing radiation, subsequent encounter',
#   'Displaced fracture of medial malleolus of unspecified tibia, initial encounter for open fracture type I or II',
#   'Other physeal fracture of lower end of humerus, right arm, sequela',
#   'Nondisplaced fracture of body of right calcaneus',
#   'Maxillary hyperplasia',
#   'Injury of digital nerve of right ring finger, sequela',
#   'Dislocation of distal interphalangeal joint of left index finger, subsequent encounter',
#   'Nondisplaced oblique fracture of shaft of right fibula, subsequent encounter for open fracture type I or II with nonunion',
#   'Toxic effect of fusel oil, accidental (unintentional), sequela',
#   'Unspecified fracture of lower end of left tibia, subsequent encounter for closed fracture with nonunion'),
#  ('Warfarin',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of bisphosphonates',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Other mechanical complication of implanted electronic neurostimulator of peripheral nerve electrode (lead)',
#   'Burn of second degree of left thigh',
#   'Nondisplaced fracture of anterior column [iliopubic] of left acetabulum',
#   'Unspecified fracture of left toe(s)',
#   'Unspecified superficial injury of right thigh, sequela'),
#  ('Enoxaparin',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of bisphosphonates',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Displaced fracture of neck of unspecified metacarpal bone, subsequent encounter for fracture with nonunion',
#   'Squamous cell carcinoma of skin of other part of trunk',
#   'Poisoning by antirheumatics, not elsewhere classified, undetermined',
#   'Multiple fractures of ribs, unspecified side',
#   '2-part nondisplaced fracture of surgical neck of right humerus, subsequent encounter for fracture with nonunion'),
#  ('SLNB',
#   'Other surgical procedures as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Cardiac catheterization as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Kidney dialysis as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Radiological procedure and radiotherapy as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Shock therapy as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Aspiration of fluid as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Partial traumatic amputation at knee level, left lower leg, subsequent encounter',
#   'Malignant neoplasm of short bones of upper limb',
#   'Encounter for examination and observation following alleged child rape',
#   'Displaced oblique fracture of shaft of unspecified tibia, subsequent encounter for closed fracture with delayed healing',
#   'Fall on and from scaffolding, sequela'),
#  ('Atorvastatin',
#   'Hyperlipidemia, unspecified',
#   'Classical phenylketonuria',
#   'Other hyperphenylalaninemias',
#   'Disorders of tryptophan metabolism',
#   'Disorder of aromatic amino-acid metabolism, unspecified',
#   'Maple-syrup-urine disease',
#   'Unspecified injury of plantar artery of left foot',
#   'Driver of pick-up truck or van injured in collision with car, pick-up truck or van in nontraffic accident',
#   'Corrosion of first degree of unspecified ankle, initial encounter',
#   'Unspecified maternal infectious and parasitic disease complicating pregnancy, second trimester',
#   'Appendico-vesicostomy status'),
#  ('ProAir HFA inhaler',
#   'Chronic obstructive pulmonary disease, unspecified',
#   'Simple chronic bronchitis',
#   'Mucopurulent chronic bronchitis',
#   'Mixed simple and mucopurulent chronic bronchitis',
#   "Unilateral pulmonary emphysema [MacLeod's syndrome]",
#   'Panlobular emphysema',
#   'Laceration of blood vessel of left middle finger',
#   'Poisoning by antiallergic and antiemetic drugs, assault',
#   'Burn of unspecified degree of head, face, and neck, unspecified site',
#   'Fracture of pubis',
#   'Displaced bicondylar fracture of right tibia, subsequent encounter for closed fracture with routine healing'),
#  ('DVT',
#   'Personal history of pulmonary embolism',
#   'Nontraumatic subarachnoid hemorrhage from carotid siphon and bifurcation',
#   'Corrosion of second degree of left lower leg, subsequent encounter',
#   'Dysphonia',
#   'Bent bone of unspecified ulna, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Poisoning by antiparkinsonism drugs and other central muscle-tone depressants, undetermined, sequela',
#   'Laceration of extensor muscle, fascia and tendon of left little finger at wrist and hand level',
#   'Monocytic leukemia, unspecified in relapse',
#   'Unspecified fracture of shaft of left tibia, subsequent encounter for open fracture type I or II with routine healing',
#   'Laceration without foreign body of right cheek and temporomandibular area, sequela',
#   'Person injured in collision between car and bus (traffic)'),
#  ('Breast IDC Grade 3',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Pressure ulcer of head, stage 3',
#   'Hypernatremia of newborn',
#   'Displacement of other cardiac electronic device, initial encounter',
#   'Juvenile osteochondrosis of patella, right knee',
#   'Hang-glider explosion injuring occupant, sequela',
#   'Unspecified nondisplaced fracture of surgical neck of right humerus, subsequent encounter for fracture with delayed healing',
#   'Other superficial injuries of left thumb, sequela'),
#  ('Trazodone',
#   'Major depressive disorder, single episode, unspecified',
#   'Manic episode, severe with psychotic symptoms',
#   'Manic episode in partial remission',
#   'Manic episode in full remission',
#   'Other manic episodes',
#   'Manic episode, unspecified',
#   'Glider (nonpowered) crash injuring occupant, subsequent encounter',
#   'Nondisplaced dome fracture of right talus, subsequent encounter for fracture with delayed healing',
#   'Other dislocation of unspecified ulnohumeral joint, subsequent encounter',
#   'Chronic multifocal osteomyelitis, left tibia and fibula',
#   'Toxic effect of ketones, assault'),
#  ('Nebulization',
#   'Chronic obstructive pulmonary disease, unspecified',
#   'Simple chronic bronchitis',
#   'Mucopurulent chronic bronchitis',
#   'Mixed simple and mucopurulent chronic bronchitis',
#   "Unilateral pulmonary emphysema [MacLeod's syndrome]",
#   'Panlobular emphysema',
#   'Pyromania',
#   'Laceration without foreign body of left elbow, initial encounter',
#   'Toxic effect of rodenticides',
#   'Poisoning by aspirin, accidental (unintentional), initial encounter',
#   'Laceration of deep palmar arch of left hand'),
#  ('COPD',
#   'Chronic obstructive pulmonary disease, unspecified',
#   'Simple chronic bronchitis',
#   'Mucopurulent chronic bronchitis',
#   'Mixed simple and mucopurulent chronic bronchitis',
#   "Unilateral pulmonary emphysema [MacLeod's syndrome]",
#   'Panlobular emphysema',
#   'Toxic effect of ingested mushrooms, undetermined',
#   'Superficial foreign body of right little finger',
#   'Skin donor',
#   'Infective myositis, right finger(s)',
#   'Acute sphenoidal sinusitis, unspecified'),
#  ('OSA',
#   'Obstructive sleep apnea (adult) (pediatric)',
#   'Insomnia, unspecified',
#   'Insomnia due to medical condition',
#   'Other insomnia',
#   'Hypersomnia, unspecified',
#   'Idiopathic hypersomnia with long sleep time',
#   'Vaginitis following delivery',
#   'Toxic effect of organophosphate and carbamate insecticides, intentional self-harm, subsequent encounter',
#   'Bitten by shark, initial encounter',
#   'Forced sexual exploitation, confirmed',
#   'Transient synovitis, multiple sites'),
#  ('Lumpectomy',
#   'Other surgical procedures as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Cardiac catheterization as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Kidney dialysis as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Radiological procedure and radiotherapy as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Shock therapy as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Aspiration of fluid as the cause of abnormal reaction of the patient, or of later complication, without mention of misadventure at the time of the procedure',
#   'Puncture wound with foreign body of right great toe without damage to nail, subsequent encounter',
#   'Unspecified physeal fracture of phalanx of right toe, initial encounter for open fracture',
#   'Nondisplaced fracture of posterior process of unspecified talus, initial encounter for closed fracture',
#   'Toxic effect of chlorine gas, accidental (unintentional), initial encounter',
#   'Stress fracture, unspecified foot, subsequent encounter for fracture with malunion'),
#  ('Antiphospholipid antibody syndrome',
#   'Antiphospholipid syndrome',
#   'Hemorrhagic disorder due to extrinsic circulating anticoagulants',
#   'Activated protein C resistance',
#   'Prothrombin gene mutation',
#   'Other primary thrombophilia',
#   'Other fracture of right lower leg, sequela',
#   'NIHSS score 32',
#   'Displaced fracture of shaft of right clavicle, initial encounter for open fracture',
#   'Corrosion of second degree of unspecified ear [any part, except ear drum], subsequent encounter',
#   'Other congenital malformations of peripheral vascular system',
#   'Salter-Harris Type II physeal fracture of lower end of right fibula, initial encounter for closed fracture'),
#  ('Omeprazole',
#   'Gastro-esophageal reflux disease without esophagitis',
#   'Eosinophilic esophagitis',
#   'Achalasia of cardia',
#   'Esophageal obstruction',
#   'Perforation of esophagus',
#   'Dyskinesia of esophagus',
#   'Unspecified superficial injury of left lower leg',
#   'Displacement of intraperitoneal dialysis catheter, initial encounter',
#   'Driver of other type car injured in collision with fixed or stationary object in traffic accident, sequela',
#   'Maternal care for (suspected) damage to fetus by radiation, not applicable or unspecified',
#   'Comminuted fracture of shaft of femur'),
#  ('Breast cancer',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Other fracture of shaft of right humerus, initial encounter for open fracture',
#   'Pedal cycle driver injured in collision with other motor vehicles in traffic accident',
#   'Nondisplaced comminuted fracture of unspecified patella, subsequent encounter for closed fracture with nonunion',
#   'Laceration with foreign body of left little finger without damage to nail, sequela',
#   'Unspecified injury to L2 level of lumbar spinal cord, initial encounter',
#   'Other secondary scoliosis, lumbar region',
#   'Superficial foreign body of nose'),
#  ('Anticoagulation',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of bisphosphonates',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Major osseous defect, unspecified shoulder region',
#   'Posterior cyclitis, right eye',
#   'Osteophyte, left elbow',
#   'Malabsorption due to intolerance, not elsewhere classified',
#   'Displaced trimalleolar fracture of unspecified lower leg, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with nonunion',
#   'Deep phlebothrombosis in pregnancy'),
#  ('Anticoagulation therapy',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of bisphosphonates',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Rheumatoid arthritis of unspecified hip with involvement of other organs and systems',
#   'Accidental twist by another person, sequela',
#   'Nondisplaced transcondylar fracture of right humerus, subsequent encounter for fracture with routine healing',
#   'Intentional self-harm by drowning and submersion while in swimming pool',
#   'Hypertrophy of bone, femur'),
#  ('Depression',
#   'Major depressive disorder, single episode, unspecified',
#   'Manic episode, severe with psychotic symptoms',
#   'Manic episode in partial remission',
#   'Manic episode in full remission',
#   'Other manic episodes',
#   'Manic episode, unspecified',
#   'Poisoning by oxytocic drugs, assault, sequela',
#   'Other incomplete lesion at C3 level of cervical spinal cord',
#   'Opioid dependence with unspecified opioid-induced disorder',
#   'Contusion and laceration of right cerebrum with loss of consciousness of 6 hours to 24 hours, subsequent encounter',
#   'Rheumatoid arthritis with rheumatoid factor of knee without organ or systems involvement'),
#  ('Hematoma',
#   'Postprocedural hematoma of skin and subcutaneous tissue following other procedure',
#   'Intraoperative hemorrhage and hematoma of skin and subcutaneous tissue complicating a dermatologic procedure',
#   'Intraoperative hemorrhage and hematoma of skin and subcutaneous tissue complicating other procedure',
#   'Accidental puncture and laceration of skin and subcutaneous tissue during a dermatologic procedure',
#   'Accidental puncture and laceration of skin and subcutaneous tissue during other procedure',
#   'Postprocedural hemorrhage of skin and subcutaneous tissue following a dermatologic procedure',
#   'Displaced fracture of anterior wall of right acetabulum, subsequent encounter for fracture with routine healing',
#   'Contusion of right shoulder, initial encounter',
#   'Displaced fracture of distal phalanx of right lesser toe(s), subsequent encounter for fracture with delayed healing',
#   'Pressure ulcer of right ankle',
#   'Traumatic rupture of other ligament of other finger at metacarpophalangeal and interphalangeal joint, sequela'),
#  ('T2DM',
#   'Type 2 diabetes mellitus without complications',
#   'Diabetes mellitus due to underlying condition with unspecified complications',
#   'Diabetes mellitus due to underlying condition without complications',
#   'Drug or chemical induced diabetes mellitus with unspecified complications',
#   'Drug or chemical induced diabetes mellitus without complications',
#   'Type 1 diabetes mellitus with unspecified complications',
#   'Animal-rider injured in unspecified transport accident, sequela',
#   'Crushing injury of unspecified external genital organs, male, sequela',
#   'Other fracture of right great toe, subsequent encounter for fracture with delayed healing',
#   'Unspecified physeal fracture of lower end of unspecified femur, sequela',
#   'Other fracture of upper and lower end of unspecified fibula, subsequent encounter for open fracture type I or II with nonunion'),
#  ('GERD',
#   'Gastro-esophageal reflux disease without esophagitis',
#   'Eosinophilic esophagitis',
#   'Achalasia of cardia',
#   'Esophageal obstruction',
#   'Perforation of esophagus',
#   'Dyskinesia of esophagus',
#   'Poisoning by, adverse effect of and underdosing of antiallergic and antiemetic drugs',
#   'Nondisplaced fracture of neck of unspecified radius, subsequent encounter for open fracture type I or II with nonunion',
#   'Displaced supracondylar fracture with intracondylar extension of lower end of unspecified femur, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Unspecified disorder of synovium and tendon, hand',
#   'Abnormal result of other cardiovascular function study'),
#  ('Sertraline',
#   'Major depressive disorder, single episode, unspecified',
#   'Manic episode, severe with psychotic symptoms',
#   'Manic episode in partial remission',
#   'Manic episode in full remission',
#   'Other manic episodes',
#   'Bipolar disorder, current episode hypomanic',
#   'Salter-Harris Type I physeal fracture of unspecified metatarsal, sequela',
#   'Other monocytic leukemia',
#   'Puncture wound without foreign body of left ring finger with damage to nail, sequela',
#   'Unspecified blepharitis left eye, unspecified eyelid',
#   'Displaced fracture of distal phalanx of left thumb, subsequent encounter for fracture with malunion'),
#  ('DVT prophylaxis',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of bisphosphonates',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Jumping or diving into unspecified water causing drowning and submersion, sequela',
#   'Displaced fracture of cuboid bone of left foot, initial encounter for open fracture',
#   'Poisoning by unspecified psychodysleptics [hallucinogens], accidental (unintentional), subsequent encounter',
#   'Fracture of coccyx, subsequent encounter for fracture with delayed healing',
#   'Bipolar disorder, current episode manic without psychotic features',
#   'Open bite of left back wall of thorax without penetration into thoracic cavity, subsequent encounter'),
#  ('Lovenox',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of bisphosphonates',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Other myositis, left hand',
#   'Other specified osteochondropathies, unspecified ankle and foot',
#   'Skeletal fluorosis, unspecified ankle and foot',
#   'Motorcycle driver injured in collision with heavy transport vehicle or bus in nontraffic accident, sequela',
#   'Coma scale, best verbal response, oriented, in the field [EMT or ambulance]'),
#  ('Warfarin',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of bisphosphonates',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Poisoning by unspecified fibrinolysis-affecting drugs, intentional self-harm, initial encounter',
#   'Strain of other specified muscles, fascia and tendons at thigh level, right thigh, subsequent encounter',
#   'Benign neoplasm of liver',
#   'Strain of extensor muscle, fascia and tendon of finger, unspecified finger at forearm level',
#   'Adverse effect of caffeine, sequela'),
#  ('Diverticulosis',
#   'Diverticulosis of intestine, part unspecified, without perforation or abscess without bleeding',
#   'Diverticulitis of small intestine with perforation and abscess without bleeding',
#   'Diverticulitis of small intestine with perforation and abscess with bleeding',
#   'Diverticulosis of small intestine without perforation or abscess with bleeding',
#   'Diverticulitis of small intestine without perforation or abscess without bleeding',
#   'Diverticulitis of small intestine without perforation or abscess with bleeding',
#   'Nondisplaced fracture of olecranon process with intraarticular extension of left ulna, subsequent encounter for open fracture type I or II with routine healing',
#   'Acute lymphangitis of left toe',
#   'Unspecified injury of other muscle(s) and tendon(s) of posterior muscle group at lower leg level, unspecified leg, sequela',
#   'Person on outside of heavy transport vehicle injured in collision with heavy transport vehicle or bus in nontraffic accident, sequela',
#   'Lateral dislocation of right ulnohumeral joint, subsequent encounter'),
#  ('Lymph node biopsy',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Injury of facial nerve',
#   'Unspecified blood type, Rh positive',
#   'Sprain of shoulder joint',
#   'Open bite of right buttock',
#   'Fall on same level from slipping, tripping and stumbling with subsequent striking against other object',
#   'Nonalcoholic steatohepatitis (NASH)',
#   'Nondisplaced fracture of fourth metatarsal bone, left foot, sequela'),
#  ('Antiphospholipid antibody syndrome',
#   'Antiphospholipid syndrome',
#   'Hemorrhagic disorder due to extrinsic circulating anticoagulants',
#   'Activated protein C resistance',
#   'Prothrombin gene mutation',
#   'Other primary thrombophilia',
#   'Acute epidemic hemorrhagic conjunctivitis (enteroviral)',
#   'Congenital hernia of bladder',
#   'Chronic osteomyelitis with draining sinus, other site',
#   'Unspecified injury of muscle, fascia and tendon of abdomen',
#   'Encounter for antibody response examination',
#   'Medullary cystic kidney'),
#  ('Iron deficiency anemia',
#   'Iron deficiency anemia, unspecified',
#   'Vitamin B12 deficiency anemia due to intrinsic factor deficiency',
#   'Vitamin B12 deficiency anemia due to selective vitamin B12 malabsorption with proteinuria',
#   'Transcobalamin II deficiency',
#   'Other dietary vitamin B12 deficiency anemia',
#   'Other vitamin B12 deficiency anemias',
#   'Mediastinal (thymic) large B-cell lymphoma, lymph nodes of inguinal region and lower limb',
#   'Toxic effect of venom of scorpion, assault, sequela',
#   'Displaced spiral fracture of shaft of unspecified femur, initial encounter for open fracture type I or II',
#   'Family history of colonic polyps',
#   'Monoarthritis, not elsewhere classified, elbow'),
#  ('Breast cancer',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Person boarding or alighting a car injured in collision with railway train or railway vehicle, sequela',
#   'Intentional self-harm by drowning and submersion after jump into swimming pool, sequela',
#   'Fracture of unspecified phalanx of left index finger',
#   'Articular disc disorder of bilateral temporomandibular joint',
#   'Terrorism involving suicide bomber, public safety official injured, initial encounter',
#   'Displaced transverse fracture of shaft of unspecified tibia, initial encounter for open fracture type IIIA, IIIB, or IIIC',
#   "Harada's disease, left eye"),
#  ('Iron studies',
#   'Iron deficiency anemia, unspecified',
#   'Vitamin B12 deficiency anemia due to intrinsic factor deficiency',
#   'Vitamin B12 deficiency anemia due to selective vitamin B12 malabsorption with proteinuria',
#   'Transcobalamin II deficiency',
#   'Other dietary vitamin B12 deficiency anemia',
#   'Other vitamin B12 deficiency anemias',
#   'Stress fracture, other site, subsequent encounter for fracture with nonunion',
#   'Pathological fracture in other disease, left foot, sequela',
#   'Subluxation and dislocation of carpometacarpal joint of thumb',
#   'Infections following infusion, transfusion and therapeutic injection',
#   'Bursitis of shoulder'),
#  ('Vitamin D deficiency',
#   'Vitamin D deficiency, unspecified',
#   'Vitamin A deficiency with conjunctival xerosis',
#   "Vitamin A deficiency with Bitot's spot and conjunctival xerosis",
#   'Vitamin A deficiency with corneal xerosis',
#   'Vitamin A deficiency with corneal ulceration and xerosis',
#   'Vitamin A deficiency with keratomalacia',
#   'Military operations involving explosion of other marine weapons, military personnel, sequela',
#   'Focal chorioretinal inflammation, macular or paramacular',
#   'Cervical disc disorders',
#   'Poisoning by unspecified psychostimulants, assault, sequela',
#   'Age-related osteoporosis with current pathological fracture, right humerus, subsequent encounter for fracture with routine healing'),
#  ('Antiphospholipid syndrome',
#   'Antiphospholipid syndrome',
#   'Hemorrhagic disorder due to extrinsic circulating anticoagulants',
#   'Activated protein C resistance',
#   'Prothrombin gene mutation',
#   'Unspecified viral hepatitis',
#   'Pain in unspecified finger(s)',
#   'Supervision of pregnancy with other poor reproductive or obstetric history',
#   'Person on outside of heavy transport vehicle injured in collision with other nonmotor vehicle in traffic accident, initial encounter',
#   'Burn of unspecified degree of unspecified lower leg, subsequent encounter',
#   'Corrosion of unspecified degree of lower back, sequela',
#   'Injury of optic tract and pathways, left side, initial encounter'),
#  ('Vitamin D level',
#   'Vitamin D deficiency, unspecified',
#   'Vitamin A deficiency with conjunctival xerosis',
#   "Vitamin A deficiency with Bitot's spot and conjunctival xerosis",
#   'Vitamin A deficiency with corneal xerosis',
#   'Vitamin A deficiency with corneal ulceration and xerosis',
#   'Vitamin A deficiency with keratomalacia',
#   'Blister (nonthermal) of left back wall of thorax',
#   'Urethral diverticulum',
#   'Choroidal rupture, unspecified eye',
#   'Major laceration of femoral artery, unspecified leg',
#   'Unspecified contact dermatitis due to dyes'),
#  ('EGD',
#   'Gastro-esophageal reflux disease without esophagitis',
#   'Achalasia of cardia',
#   'Perforation of esophagus',
#   'Diverticulum of esophagus, acquired',
#   'Disease of esophagus, unspecified',
#   'Acute gastric ulcer with perforation',
#   'Non-pressure chronic ulcer of other part of unspecified foot with necrosis of muscle',
#   'Unspecified dislocation of unspecified radial head, initial encounter',
#   'Continuing pregnancy after spontaneous abortion of one fetus or more, unspecified trimester, fetus 5',
#   'Malignant neoplasm of unspecified part of unspecified adrenal gland',
#   'Nondisplaced fracture of lateral condyle of left tibia, subsequent encounter for closed fracture with routine healing'),
#  ('DVT/PE',
#   'Personal history of pulmonary embolism',
#   'Contusion, laceration, and hemorrhage of brainstem without loss of consciousness, sequela',
#   'Underdosing of rifampicins, sequela',
#   'Displaced fracture of medial cuneiform of left foot, subsequent encounter for fracture with malunion',
#   'Transient alteration of awareness',
#   'Other injury of other muscles, fascia and tendons at shoulder and upper arm level, right arm, sequela',
#   'Poisoning by other general anesthetics, accidental (unintentional)',
#   'Unspecified injury at T1 level of thoracic spinal cord, sequela',
#   'Burn of second degree of multiple right fingers (nail), not including thumb',
#   'Residual hemorrhoidal skin tags',
#   'Fall into swimming pool striking wall causing drowning and submersion, initial encounter'),
#  ('Ferric gluconate',
#   'Iron deficiency anemia, unspecified',
#   'Vitamin B12 deficiency anemia due to intrinsic factor deficiency',
#   'Vitamin B12 deficiency anemia due to selective vitamin B12 malabsorption with proteinuria',
#   'Transcobalamin II deficiency',
#   'Other dietary vitamin B12 deficiency anemia',
#   'Other vitamin B12 deficiency anemias',
#   'Abnormal level of other drugs, medicaments and biological substances in specimens from respiratory organs and thorax',
#   'Unspecified superficial injuries of throat, sequela',
#   'Unspecified glider (nonpowered) accident injuring occupant, sequela',
#   'Anterior dislocation of right humerus',
#   'Occlusion and stenosis of unspecified carotid artery'),
#  ('PPI',
#   'Gastro-esophageal reflux disease without esophagitis',
#   'Eosinophilic esophagitis',
#   'Achalasia of cardia',
#   'Esophageal obstruction',
#   'Perforation of esophagus',
#   'Dyskinesia of esophagus',
#   'Open bite of right thumb with damage to nail, subsequent encounter',
#   'Palmar fascial fibromatosis [Dupuytren]',
#   'Other fracture of upper end of left tibia, initial encounter for closed fracture',
#   'Unspecified physeal fracture of upper end of humerus, unspecified arm, initial encounter for closed fracture',
#   'Other forms of blastomycosis'),
#  ('Hyperlipidemia',
#   'Hyperlipidemia, unspecified',
#   'Classical phenylketonuria',
#   'Other hyperphenylalaninemias',
#   'Disorders of tryptophan metabolism',
#   'Disorder of aromatic amino-acid metabolism, unspecified',
#   'Maple-syrup-urine disease',
#   'Other physeal fracture of lower end of right tibia, subsequent encounter for fracture with delayed healing',
#   'Traumatic subdural hemorrhage with loss of consciousness of any duration with death due to other cause before regaining consciousness, subsequent encounter',
#   'Alcohol use, unspecified with intoxication, unspecified',
#   'Displaced midcervical fracture of unspecified femur',
#   'Displaced trimalleolar fracture of right lower leg, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with nonunion'),
#  ('COPD',
#   'Chronic obstructive pulmonary disease, unspecified',
#   'Simple chronic bronchitis',
#   'Mucopurulent chronic bronchitis',
#   'Mixed simple and mucopurulent chronic bronchitis',
#   "Unilateral pulmonary emphysema [MacLeod's syndrome]",
#   'Panlobular emphysema',
#   'Laceration of vein at forearm level, right arm, subsequent encounter',
#   'Diabetes mellitus due to underlying condition with moderate nonproliferative diabetic retinopathy with macular edema, left eye',
#   'Unspecified complication following complete or unspecified spontaneous abortion',
#   'Ulnohumeral (joint) sprain of right elbow',
#   'Other displaced fracture of upper end of left humerus, sequela'),
#  ('Subtherapeutic INR',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of bisphosphonates',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Other exposure to uncontrolled fire in building or structure, subsequent encounter',
#   'Other specified helminthiases',
#   'Hemiplegia and hemiparesis following nontraumatic subarachnoid hemorrhage affecting right dominant side',
#   'Laceration with foreign body of unspecified buttock, subsequent encounter',
#   'Displaced longitudinal fracture of unspecified patella, sequela'),
#  ('DICLOFENAC GEL',
#   'Trochanteric bursitis, right hip',
#   'Bursitis, unspecified hand',
#   'Bursitis, right hand',
#   'Bursitis, left hand',
#   'Olecranon bursitis, unspecified elbow',
#   'Olecranon bursitis, right elbow',
#   'Complete traumatic amputation of left shoulder and upper arm, level unspecified',
#   'Drowning and submersion due to being thrown overboard by motion of canoe or kayak, sequela',
#   'Poisoning by other psychostimulants, intentional self-harm',
#   'Superficial foreign body, right great toe, subsequent encounter',
#   'Unspecified subluxation of left middle finger'),
#  ('INR',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of bisphosphonates',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Torsion of right ovary and ovarian pedicle',
#   'Minor laceration of superior vena cava, sequela',
#   'Salter-Harris Type IV physeal fracture of phalanx of left toe, subsequent encounter for fracture with malunion',
#   "Meningoencephalitis in Chagas' disease",
#   'Corrosion of unspecified degree of unspecified foot, sequela'),
#  ('Depression',
#   'Major depressive disorder, single episode, unspecified',
#   'Manic episode, severe with psychotic symptoms',
#   'Manic episode in partial remission',
#   'Manic episode in full remission',
#   'Other manic episodes',
#   'Manic episode, unspecified',
#   'Salter-Harris Type I physeal fracture of phalanx of unspecified toe, subsequent encounter for fracture with delayed healing',
#   'Unspecified injury of extensor muscle, fascia and tendon of right middle finger at forearm level, sequela',
#   'Laceration with foreign body, left knee, subsequent encounter',
#   'Sprain of metacarpophalangeal joint of unspecified thumb, subsequent encounter',
#   'Major osseous defect, unspecified hand'),
#  ('Right trochanteric bursitis',
#   'Trochanteric bursitis, right hip',
#   'Bursitis, unspecified hand',
#   'Bursitis, right hand',
#   'Bursitis, left hand',
#   'Olecranon bursitis, unspecified elbow',
#   'Olecranon bursitis, right elbow',
#   'Blister (nonthermal) of scalp, sequela',
#   'Contusion of hip',
#   'Nondisplaced comminuted fracture of shaft of right tibia, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Burn of second degree of left thigh',
#   'Partial placenta previa with hemorrhage, third trimester'),
#  ('BRCA1 gene mutation',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Poisoning by selective serotonin reuptake inhibitors, accidental (unintentional), initial encounter',
#   'Open bite of left front wall of thorax without penetration into thoracic cavity, initial encounter',
#   'Toxic effect of venom of other reptiles, assault, sequela',
#   'Superficial foreign body, unspecified lesser toe(s), sequela',
#   'Unspecified nephritic syndrome',
#   'Precipitous drop in hematocrit',
#   'Infection of nipple associated with pregnancy, unspecified trimester'),
#  ('Malabsorption',
#   'Vitamin D deficiency, unspecified',
#   'Vitamin A deficiency with conjunctival xerosis',
#   "Vitamin A deficiency with Bitot's spot and conjunctival xerosis",
#   'Vitamin A deficiency with corneal xerosis',
#   'Vitamin A deficiency with corneal ulceration and xerosis',
#   'Vitamin A deficiency with keratomalacia',
#   'Displacement of internal fixation device of bone of left forearm',
#   'Puncture wound without foreign body of unspecified front wall of thorax with penetration into thoracic cavity, sequela',
#   'Gout due to renal impairment, ankle and foot',
#   'Nondisplaced fracture of second metatarsal bone, left foot, subsequent encounter for fracture with routine healing',
#   'Twin pregnancy, monochorionic/monoamniotic, unspecified trimester'),
#  ('IV iron infusion',
#   'Iron deficiency anemia, unspecified',
#   'Vitamin B12 deficiency anemia due to intrinsic factor deficiency',
#   'Vitamin B12 deficiency anemia due to selective vitamin B12 malabsorption with proteinuria',
#   'Transcobalamin II deficiency',
#   'Other dietary vitamin B12 deficiency anemia',
#   'Other vitamin B12 deficiency anemias',
#   'Displaced fracture of medial condyle of unspecified tibia, subsequent encounter for open fracture type I or II with delayed healing',
#   'Poisoning by antiparkinsonism drugs and other central muscle-tone depressants, undetermined, subsequent encounter',
#   'Boutonniere deformity of left finger(s)',
#   'Insomnia due to medical condition',
#   'Displaced fracture of middle phalanx of right middle finger, subsequent encounter for fracture with nonunion'),
#  ('Lupus anticoagulant',
#   'Antiphospholipid syndrome',
#   'Hemorrhagic disorder due to extrinsic circulating anticoagulants',
#   'Activated protein C resistance',
#   'Prothrombin gene mutation',
#   'Displaced fracture of olecranon process with intraarticular extension of left ulna, subsequent encounter for open fracture type I or II with delayed healing',
#   'Disorder of mineral metabolism, unspecified',
#   'Legal intervention involving bayonet, suspect injured, subsequent encounter',
#   'Nondisplaced fracture of greater trochanter of right femur, subsequent encounter for closed fracture with routine healing',
#   'Dislocation of proximal interphalangeal joint of left ring finger, initial encounter',
#   'Other chronic nonsuppurative otitis media, unspecified ear',
#   'Fever of other and unknown origin'),
#  ('Ferritin',
#   'Iron deficiency anemia, unspecified',
#   'Vitamin B12 deficiency anemia due to intrinsic factor deficiency',
#   'Vitamin B12 deficiency anemia due to selective vitamin B12 malabsorption with proteinuria',
#   'Transcobalamin II deficiency',
#   'Other dietary vitamin B12 deficiency anemia',
#   'Other vitamin B12 deficiency anemias',
#   'Other conditions associated with Lyme disease',
#   'Sled accident',
#   'Injury of digital nerve of left ring finger, subsequent encounter',
#   'Open bite of abdominal wall, unspecified quadrant with penetration into peritoneal cavity',
#   'Unstable burst fracture of fourth lumbar vertebra, subsequent encounter for fracture with nonunion'),
#  ('Sentinel lymph node biopsy',
#   'Malignant neoplasm of unspecified site of left female breast',
#   'Malignant neoplasm of unspecified site of right male breast',
#   'Malignant neoplasm of unspecified site of left male breast',
#   'Malignant neoplasm of unspecified site of unspecified male breast',
#   'Pedestrian with other conveyance injured in collision with car, pick-up truck or van in traffic accident',
#   'Personal history of drug therapy',
#   'Displaced fracture of greater tuberosity of unspecified humerus, initial encounter for open fracture',
#   'Other fracture of upper end of right ulna, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Other fracture of first thoracic vertebra, initial encounter for closed fracture',
#   'Poisoning by, adverse effect of and underdosing of centrally-acting and adrenergic- neuron-blocking agents',
#   'Corrosions involving 80-89% of body surface with 0% to 9% third degree corrosion'),
#  ('OSA',
#   'Obstructive sleep apnea (adult) (pediatric)',
#   'Insomnia, unspecified',
#   'Insomnia due to medical condition',
#   'Other insomnia',
#   'Hypersomnia, unspecified',
#   'Idiopathic hypersomnia with long sleep time',
#   'Toxic effect of harmful algae and algae toxins, undetermined, subsequent encounter',
#   'Unspecified open-angle glaucoma, moderate stage',
#   'Contusion of head of pancreas, initial encounter',
#   'Displaced midcervical fracture of unspecified femur, subsequent encounter for closed fracture with malunion',
#   'Car driver injured in collision with other type car in nontraffic accident, subsequent encounter'),
#  ('A1C',
#   'Type 2 diabetes mellitus without complications',
#   'Diabetes mellitus due to underlying condition with unspecified complications',
#   'Diabetes mellitus due to underlying condition without complications',
#   'Drug or chemical induced diabetes mellitus with unspecified complications',
#   'Drug or chemical induced diabetes mellitus without complications',
#   'Type 1 diabetes mellitus with unspecified complications',
#   'Infection of amniotic sac and membranes, unspecified, third trimester, fetus 2',
#   'Wedge compression fracture of T7-T8 vertebra, initial encounter for open fracture',
#   'Nondisplaced fracture of neck of unspecified radius, subsequent encounter for closed fracture with malunion',
#   'Pedestrian on roller-skates injured in collision with railway train or railway vehicle, unspecified whether traffic or nontraffic accident, sequela',
#   'Injury of cranial nerve'),
#  ('Fatigue',
#   'Iron deficiency anemia, unspecified',
#   'Vitamin B12 deficiency anemia due to intrinsic factor deficiency',
#   'Vitamin B12 deficiency anemia due to selective vitamin B12 malabsorption with proteinuria',
#   'Transcobalamin II deficiency',
#   'Other dietary vitamin B12 deficiency anemia',
#   'Other vitamin B12 deficiency anemias',
#   'Osteomyelitis of vertebra, sacral and sacrococcygeal region',
#   'Malignant neoplasm of nipple and areola, left male breast',
#   'Other meniscus derangements, posterior horn of lateral meniscus',
#   'Other secondary kyphosis, thoracic region',
#   'Kaschin-Beck disease, hip'),
#  ('Vascular surgery',
#   'Long term (current) use of anticoagulants',
#   'Long term (current) use of inhaled steroids',
#   'Long term (current) use of systemic steroids',
#   'Long term (current) use of aspirin',
#   'Long term (current) use of bisphosphonates',
#   'Long term (current) use of oral hypoglycemic drugs',
#   'Minor laceration of right kidney',
#   'Assault by sharp glass, sequela',
#   'Acute maxillary sinusitis',
#   'Laceration with foreign body of unspecified finger with damage to nail',
#   'Poisoning by antiviral drugs, assault, sequela'),
#  ('T2DM',
#   'Type 2 diabetes mellitus without complications',
#   'Diabetes mellitus due to underlying condition with unspecified complications',
#   'Diabetes mellitus due to underlying condition without complications',
#   'Drug or chemical induced diabetes mellitus with unspecified complications',
#   'Drug or chemical induced diabetes mellitus without complications',
#   'Type 1 diabetes mellitus with unspecified complications',
#   'Torus fracture of upper end of right tibia, initial encounter for closed fracture',
#   'Acute infarction of intestine, part unspecified',
#   'Posterior displaced fracture of sternal end of left clavicle, subsequent encounter for fracture with malunion',
#   'Polytrichia',
#   '(Induced) termination of pregnancy with other and unspecified complications'),
#  ('Enoxaparin',
#   'Long term (current) use of anticoagulants',
# ...
#  ('Troponin',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Laceration of muscle(s) and tendon(s) of peroneal muscle group at lower leg level, left leg, subsequent encounter',
#   'Other rheumatoid arthritis with rheumatoid factor of right elbow',
#   'Nondisplaced fracture of shaft of left clavicle',
#   'Toxic effect of venom of other North and South American snake, intentional self-harm, initial encounter',
#   'Poisoning by macrolides, undetermined',
#   'Non-pressure chronic ulcer of buttock with necrosis of muscle',
#   'Other specified crystal arthropathies, right shoulder',
#   'Frostbite with tissue necrosis of unspecified ear',
#   'Eructation',
#   'Other mechanical complication of artificial skin graft and decellularized allodermis, sequela'),
#  ('Ranitidine',
#   'Gastro-esophageal reflux disease without esophagitis',
#   'Eosinophilic esophagitis',
#   'Achalasia of cardia',
#   'Esophageal obstruction',
#   'Perforation of esophagus',
#   'Dyskinesia of esophagus',
#   'Squamous blepharitis right lower eyelid',
#   'Nondisplaced fracture of olecranon process with intraarticular extension of right ulna, initial encounter for closed fracture',
#   'Displaced segmental fracture of shaft of right fibula, initial encounter for open fracture type IIIA, IIIB, or IIIC',
#   'Monoarthritis, not elsewhere classified, right wrist',
#   'Obesity, unspecified'),
#  ('LAD',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Drug or chemical induced diabetes mellitus with ketoacidosis with coma',
#   "Reiter's disease, left wrist",
#   'Nondisplaced longitudinal fracture of right patella, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing',
#   'Perforation due to foreign body accidentally left in body following surgical operation, subsequent encounter',
#   'Displaced oblique fracture of shaft of humerus, left arm, subsequent encounter for fracture with nonunion',
#   'Displaced fracture of proximal phalanx of left thumb, subsequent encounter for fracture with malunion',
#   'Unspecified foreign body in other parts of respiratory tract causing asphyxiation, sequela',
#   'Adult physical abuse, suspected',
#   'Contusion of right little finger without damage to nail, subsequent encounter',
#   'Subluxation of metatarsophalangeal joint of left lesser toe(s), initial encounter'),
#  ('Fixed perfusion defect',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Causalgia of bilateral lower limbs',
#   'Other air transport accident involving military aircraft, initial encounter',
#   'Person on outside of heavy transport vehicle injured in collision with pedal cycle in nontraffic accident, sequela',
#   'Underdosing of digestants',
#   'Other meniscus derangements, anterior horn of lateral meniscus',
#   'Superficial frostbite of unspecified finger(s), subsequent encounter',
#   'Salter-Harris Type III physeal fracture of upper end of humerus, unspecified arm, subsequent encounter for fracture with delayed healing',
#   'Fracture of angle of mandible, unspecified side, sequela',
#   'Burn of third degree of back of unspecified hand, sequela',
#   'Neoplasm of unspecified behavior of other genitourinary organ'),
#  ('Elevated left ventricular filling pressure',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Renal failure following (induced) termination of pregnancy',
#   'Corrosion of second degree of multiple sites of lower limb, except ankle and foot',
#   'Injury of radial nerve at forearm level, right arm, initial encounter',
#   'Other osteoporosis with current pathological fracture, right forearm, subsequent encounter for fracture with nonunion',
#   'Injury of right internal carotid artery, intracranial portion, not elsewhere classified with loss of consciousness of any duration with death due to other cause prior to regaining consciousness, sequela',
#   'Acute lymphangitis of umbilicus',
#   'Puncture wound without foreign body of unspecified thumb without damage to nail',
#   'Unspecified car occupant injured in collision with pedal cycle in traffic accident, subsequent encounter',
#   'Presence of artificial larynx',
#   'Monoplegia of upper limb following other cerebrovascular disease affecting right dominant side'),
#  ('Aspirin',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Lymphoblastic (diffuse) lymphoma, intrapelvic lymph nodes',
#   'Superficial frostbite of unspecified arm, subsequent encounter',
#   'Military operations involving incendiary bullet, civilian, initial encounter',
#   'Displaced transverse fracture of shaft of left tibia, initial encounter for open fracture type I or II',
#   'Toxic effect of contact with venomous toad, intentional self-harm',
#   'Crushing injury of larynx and trachea',
#   'Poisoning by, adverse effect of and underdosing of vitamins',
#   'Adverse effect of other fibrinolysis-affecting drugs',
#   'Other superficial bite of unspecified part of head, subsequent encounter',
#   'Corrosion of second degree of right wrist, initial encounter'),
#  ('Ramus Mid Left Cx',
#   'Presence of coronary angioplasty implant and graft',
#   'Other contact with and (suspected) exposures hazardous to health',
#   'Asymptomatic menopausal state',
#   'Physical restraint status',
#   'Other specified health status',
#   'Long term (current) use of non-steroidal anti-inflammatories (NSAID)',
#   'Unspecified fracture of right ischium',
#   'Burn of unspecified degree of chin, subsequent encounter',
#   'Nondisplaced oblique fracture of shaft of left tibia, initial encounter for open fracture type I or II',
#   'Acute sphenoidal sinusitis',
#   'Bitten by other birds, sequela'),
#  ('CAD',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Unspecified fracture of upper end of right tibia',
#   'Strain of unspecified muscle(s) and tendon(s) at lower leg level, unspecified leg, subsequent encounter',
#   'Postinfectious acute disseminated encephalitis and encephalomyelitis (postinfectious ADEM)',
#   'Other subluxation of unspecified radial head, initial encounter',
#   'Military operations involving combat using blunt or piercing object, military personnel, initial encounter',
#   'Salter-Harris Type I physeal fracture of upper end of left femur, subsequent encounter for fracture with routine healing',
#   'Placenta previa',
#   'Car driver injured in collision with fixed or stationary object in traffic accident, subsequent encounter',
#   'Pre-existing essential hypertension complicating the puerperium',
#   'Open angle with borderline findings, high risk, bilateral'),
#  ('Metoprolol',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Retinal detachment with multiple breaks, left eye',
#   'Laceration with foreign body of left front wall of thorax with penetration into thoracic cavity, subsequent encounter',
#   'Congenital shortening of lower limb, bilateral',
#   'Fracture of unspecified part of neck of left femur, subsequent encounter for closed fracture with malunion',
#   'Person boarding or alighting a pick-up truck or van injured in collision with pedal cycle, subsequent encounter',
#   'Car passenger injured in collision with pedestrian or animal in nontraffic accident, sequela',
#   "Monteggia's fracture of left ulna, initial encounter for closed fracture",
#   'Traumatic amputation (partial) of part of thorax, except breast, initial encounter',
#   'Nondisplaced segmental fracture of shaft of left fibula, subsequent encounter for open fracture type I or II with routine healing',
#   'Displaced spiral fracture of shaft of radius, right arm, subsequent encounter for open fracture type I or II with delayed healing'),
#  ('Nitroglycerin',
#   'Atherosclerotic heart disease of native coronary artery with unspecified angina pectoris',
#   'Other complication of vascular dialysis catheter, initial encounter',
#   'Displaced midcervical fracture of unspecified femur, initial encounter for closed fracture',
#   'Nondisplaced segmental fracture of shaft of unspecified tibia, subsequent encounter for closed fracture with routine healing',
#   'Toxic effect of fiberglass, undetermined, subsequent encounter',
#   'Poisoning by enzymes, assault, initial encounter',
#   'Other fracture of upper and lower end of left fibula, subsequent encounter for closed fracture with malunion',
#   'Immunization not carried out for other reason',
#   'Parachutist injured on landing, sequela',
#   'Unspecified occupant of pick-up truck or van injured in noncollision transport accident in traffic accident, subsequent encounter',
#   'Inflammatory disorders of breast'),
#  ('BiV ICD',
#   'Encounter for adjustment and management of automatic implantable cardiac defibrillator',
#   'Encounter for adjustment and management of implanted visual substitution device',
#   'Encounter for adjustment and management of cerebrospinal fluid drainage device',
#   'Encounter for adjustment and management of neurostimulator',
#   'Encounter for adjustment and management of other implanted nervous system device',
#   'Encounter for adjustment or removal of myringotomy device (stent) (tube)',
#   'Complete uterovaginal prolapse',
#   'Preterm labor third trimester with preterm delivery third trimester, fetus 5',
#   'Maternal care for (suspected) damage to fetus by other medical procedures, fetus 1',
#   'Toxic effect of mercury and its compounds, assault',
#   'Toxic effect of other halogen derivatives of aliphatic hydrocarbons, undetermined, initial encounter'),
#  ('Respiratory acidosis',
#   'Mixed disorder of acid-base balance',
#   'Classical phenylketonuria',
#   'Other hyperphenylalaninemias',
#   'Disorders of tryptophan metabolism',
#   'Disorder of aromatic amino-acid metabolism, unspecified',
#   'Maple-syrup-urine disease',
#   'Laceration without foreign body, left foot, sequela',
#   'Malignant neoplasm of lower-inner quadrant of right male breast',
#   'Activity, water skiing and wake boarding',
#   'Gastric contents in trachea',
#   'Displaced fracture of olecranon process without intraarticular extension of left ulna, subsequent encounter for open fracture type IIIA, IIIB, or IIIC with delayed healing'),
#  ('Schizophrenia',
#   'Paranoid schizophrenia',
#   'Schizoaffective disorder, bipolar type',
#   'Schizoaffective disorder, depressive type',
#   'Other schizoaffective disorders',
#   'Salter-Harris Type I physeal fracture of lower end of radius, unspecified arm, subsequent encounter for fracture with routine healing',
#   'Carbuncle of perineum',
#   'Unspecified fracture of lower end of left femur, subsequent encounter for open fracture type I or II with delayed healing',
#   'Displaced fracture of distal phalanx of right ring finger, sequela',
#   'Other disorders of the eye following cataract surgery',
#   'Unspecified dislocation of acromioclavicular joint',
#   'Iliac crest spur'),
#  ('Hyperlipidemia',
#   'Hyperlipidemia, unspecified',
#   'Classical phenylketonuria',
#   'Other hyperphenylalaninemias',
#   'Disorders of tryptophan metabolism',
#   'Disorder of aromatic amino-acid metabolism, unspecified',
#   'Maple-syrup-urine disease',
#   'Other hypertrophic osteoarthropathy, right thigh',
#   'Nondisplaced fracture (avulsion) of lateral epicondyle of left humerus',
#   'Corrosion of third degree of left knee, initial encounter',
#   'Unspecified myringitis',
#   'Toxic effect of nitroderivatives and aminoderivatives of benzene and its homologues, undetermined, initial encounter'),
#  ('Renal cancer',
#   'Personal history of other malignant neoplasm of kidney',
#   'Poisoning by unspecified drugs primarily affecting the autonomic nervous system, assault, subsequent encounter',
#   'Physical abuse complicating pregnancy, third trimester',
#   'Unspecified deformity of finger(s)',
#   'Other osteoporosis with current pathological fracture, left hand, subsequent encounter for fracture with malunion',
#   'Unspecified physeal fracture of upper end of humerus, right arm, initial encounter for closed fracture',
#   'Other oral mucositis (ulcerative)',
#   'Radiculopathy, thoracic region',
#   'Displaced fracture of proximal phalanx of right great toe, initial encounter for open fracture',
#   'Hallucinogen dependence with hallucinogen persisting perception disorder (flashbacks)',
#   "Galeazzi's fracture of left radius, initial encounter for open fracture type IIIA, IIIB, or IIIC"),
#  ('Hypoxia',
#   'Acute respiratory failure with hypoxia',
#   'Chronic respiratory failure, unspecified whether with hypoxia or hypercapnia',
#   'Chronic respiratory failure with hypercapnia',
#   'Acute and chronic respiratory failure, unspecified whether with hypoxia or hypercapnia',
#   'Acute and chronic respiratory failure with hypercapnia',
#   'Respiratory failure, unspecified, unspecified whether with hypoxia or hypercapnia',
#   'Malignant neoplasm of left ovary',
#   'Disorder of amniotic fluid and membranes, unspecified, second trimester, other fetus',
#   'Posterior subluxation of proximal end of tibia, right knee, initial encounter',
#   'Military operations involving accidental detonation of onboard marine weapons, civilian, subsequent encounter',
#   'Puncture wound without foreign body of unspecified lesser toe(s) without damage to nail, initial encounter'),
#  ('Metabolic acidosis',
#   'Mixed disorder of acid-base balance',
#   'Classical phenylketonuria',
#   'Other hyperphenylalaninemias',
#   'Disorders of tryptophan metabolism',
#   'Disorder of aromatic amino-acid metabolism, unspecified',
#   'Maple-syrup-urine disease',
#   'Toxic liver disease with hepatic necrosis',
#   'Laceration without foreign body of scalp, initial encounter',
#   'Other specified local infections of the skin and subcutaneous tissue',
#   'Military firearm discharge, undetermined intent',
#   'Other injury of esophagus (thoracic part)'),
#  ('Hypotension',
#   'Cardiogenic shock',
#   'Drug induced fever',
#   'Fever, unspecified',
#   'Neoplastic (malignant) related fatigue',
#   'Weakness',
#   'Functional quadriplegia',
#   'Unspecified injury of plantar artery of foot',
#   'Other calcification of muscle, left ankle and foot',
#   'Unspecified injury of flexor muscle, fascia and tendon of unspecified finger at wrist and hand level, sequela',
#   'Superficial foreign body of thigh',
#   'Other osteoporosis with current pathological fracture, right shoulder, subsequent encounter for fracture with delayed healing'),
#  ('Intubation',
#   'Acute respiratory failure with hypoxia',
#   'Chronic respiratory failure, unspecified whether with hypoxia or hypercapnia',
#   'Chronic respiratory failure with hypoxia',
#   'Chronic respiratory failure with hypercapnia',
#   'Acute and chronic respiratory failure, unspecified whether with hypoxia or hypercapnia',
#   'Adverse effect of other drugs, medicaments and biological substances, initial encounter',
#   'Partial traumatic amputation at level between elbow and wrist, right arm, initial encounter',
#   'Sprain of deltoid ligament of left ankle, subsequent encounter',
#   'Other tear of medial meniscus, current injury, left knee',
#   'Unspecified infection of urinary tract in pregnancy, third trimester',
#   'Palindromic rheumatism, elbow'),
#  ('Chronic kidney disease (CKD)',
#   'Hypertensive chronic kidney disease with stage 1 through stage 4 chronic kidney disease, or unspecified chronic kidney disease',
#   'Hypertensive heart disease with heart failure',
#   'Hypertensive heart disease without heart failure',
#   'Renovascular hypertension',
#   'Hypertension secondary to other renal disorders',
#   'Hypertension secondary to endocrine disorders',
#   'Dislocation of other parts of thorax, initial encounter',
#   'Anterior displaced fracture of sternal end of right clavicle, initial encounter for open fracture',
#   'Injury of muscle and tendon of long flexor muscle of toe at ankle and foot level',
#   'Assault by pushing or placing victim in front of (subway) train',
#   'Person on outside of car injured in collision with sport utility vehicle in nontraffic accident'),
#  ...]

# %%
prova = random.sample(touples, 1)
for term, code, neg1, neg2, neg3, neg4, neg5, neg6, neg7, neg8, neg9, neg10 in prova:
    print(term)
    print(code)
    print(neg1)
    print(neg2)
    print(neg3)
    print(neg4)
    print(neg5)
    print(neg6)
    print(neg7)
    print(neg8)
    print(neg9)
    print(neg10)
    print()
# Out:
# Myocarditis
# Personal history of other diseases of the circulatory system
# Personal history of tuberculosis
# Personal history of gestational diabetes
# Personal history of latent tuberculosis infection
# Personal history of other infectious and parasitic diseases
# Personal history of diabetic foot ulcer
# Radiculopathy, lumbosacral region
# Military operation involving other effects of nuclear weapons, military personnel
# Contusion of right ring finger with damage to nail, subsequent encounter
# Unspecified fracture of second metacarpal bone, right hand, initial encounter for open fracture
# Hereditary and idiopathic neuropathy

# %%
# salva il dataset di triple come un dataframe di pandas con 3 colonne "anchor", "positive" e "negative"
df = pd.DataFrame(touples, columns=["anchor", "positive", "negative_1", "negative_2", "negative_3", "negative_4", "negative_5", "negative_6", "negative_7", "negative_8", "negative_9", "negative_10"])
df.to_csv(OUTPUT_DIR + "touples.csv", index=False)

# %%
df
# Out:
#                               anchor  \
# 0              Anterior exenteration
# 1                       Atorvastatin
# 2                           Urostomy
# 3                     Bladder cancer
# 4                           Losartan
# ...                              ...
# 473541                    Lamivudine
# 473542                       Rituxan
# 473543                          MGUS
# 473544             Aminotransferases
# 473545  Protein-Calorie Malnutrition
#
#                                                  positive  \
# 0                      Malignant neoplasm of bladder neck
# 1                             Hyperlipidemia, unspecified
# 2                      Malignant neoplasm of bladder neck
# 3                      Malignant neoplasm of bladder neck
# 4                        Essential (primary) hypertension
# ...                                                   ...
# 473541  Adverse effect of antineoplastic and immunosup...
# 473542          Encounter for antineoplastic chemotherapy
# 473543                              Monoclonal gammopathy
# 473544  Nonspecific elevation of levels of transaminas...
# 473545    Unspecified severe protein-calorie malnutrition
#
#                                                negative_1  \
# 0       Malignant neoplasm of unspecified kidney, exce...
# 1                               Other lactose intolerance
# 2        Malignant neoplasm of urinary organ, unspecified
# 3                Malignant neoplasm of right renal pelvis
# 4                                  Portal vein thrombosis
# ...                                                   ...
# 473541  Poisoning by antineoplastic and immunosuppress...
# 473542            Encounter for other specified aftercare
# 473543         Neoplasm of uncertain behavior of prostate
# 473544            Elevated erythrocyte sedimentation rate
# 473545                      Postprocedural hypothyroidism
#
#                                                negative_2  \
# 0          Malignant neoplasm of unspecified renal pelvis
# 1                   Lipomatosis, not elsewhere classified
# 2       Malignant neoplasm of overlapping sites of uri...
# 3                           Malignant neoplasm of urethra
# 4         Cardiomyopathy in diseases classified elsewhere
# ...                                                   ...
# 473541  Poisoning by antineoplastic and immunosuppress...
# 473542    Encounter for therapeutic drug level monitoring
# 473543  Neoplasm of uncertain behavior of respiratory ...
# 473544               Other abnormality of red blood cells
# 473545                         Dietary calcium deficiency
#
#                                                negative_3  \
# 0                       Malignant neoplasm of left ureter
# 1                          Mucopolysaccharidosis, type II
# 2                       Malignant neoplasm of left ureter
# 3                      Malignant neoplasm of right ureter
# 4       Endocarditis and heart valve disorders in dise...
# ...                                                   ...
# 473541  Poisoning by antineoplastic and immunosuppress...
# 473542  Unspecified superficial injury of left thigh, ...
# 473543   Refractory cytopenia with multilineage dysplasia
# 473544   Other specified abnormalities of plasma proteins
# 473545  Postprocedural adrenocortical (-medullary) hyp...
#
#                                                negative_4  \
# 0               Malignant neoplasm of paraurethral glands
# 1       Hyperuricemia without signs of inflammatory ar...
# 2                           Malignant neoplasm of urethra
# 3        Malignant neoplasm of urinary organ, unspecified
# 4                         Endocarditis, valve unspecified
# ...                                                   ...
# 473541  Poisoning by antineoplastic and immunosuppress...
# 473542  Nondisplaced fracture of triquetrum [cuneiform...
# 473543            Neoplasm of uncertain behavior of colon
# 473544   Abnormal finding of blood chemistry, unspecified
# 473545                        Dietary selenium deficiency
#
#                                                negative_5  \
# 0                 Malignant neoplasm of left renal pelvis
# 1                           Volume depletion, unspecified
# 2                 Malignant neoplasm of left renal pelvis
# 3                       Malignant neoplasm of left ureter
# 4               Rheumatic fever without heart involvement
# ...                                                   ...
# 473541  Underdosing of antineoplastic and immunosuppre...
# 473542  Diseases of the circulatory system complicatin...
# 473543           Neoplasm of uncertain behavior of larynx
# 473544  Finding of other drugs of addictive potential ...
# 473545                      Sequelae of hyperalimentation
#
#                                                negative_6  \
# 0                   Unspecified kyphosis, cervical region
# 1       Glaucoma secondary to other eye disorders, uns...
# 2                                   Indeterminate leprosy
# 3       Crepitant synovitis (acute) (chronic), unspeci...
# 4       Complete traumatic metacarpophalangeal amputat...
# ...                                                   ...
# 473541                   Pain associated with micturition
# 473542  Displaced fracture of olecranon process with i...
# 473543                Calcific tendinitis, multiple sites
# 473544       Burn of first degree of left axilla, sequela
# 473545  War operations involving destruction of aircra...
#
#                                                negative_7  \
# 0       Unspecified superficial injuries of left back ...
# 1       Fracture of one rib, left side, subsequent enc...
# 2       Poisoning by other viral vaccines, accidental ...
# 3       Legal intervention, means unspecified, law enf...
# 4       Poisoning by other primarily systemic and hema...
# ...                                                   ...
# 473541  Other specified injury of blood vessel of righ...
# 473542  Legal intervention involving unspecified sharp...
# 473543  Asphyxiation due to being trapped in a (discar...
# 473544  Type 1 diabetes mellitus with diabetic macular...
# 473545                                           Gas pain
#
#                                                negative_8  \
# 0                             Dome fracture of acetabulum
# 1       Toxic effect of other tobacco and nicotine, ac...
# 2       Fracture of unspecified metatarsal bone(s), ri...
# 3                    Other paralytic strabismus, left eye
# 4       Other specified injury of other blood vessels ...
# ...                                                   ...
# 473541  Laceration of extensor or abductor muscles, fa...
# 473542  Displaced apophyseal fracture of right femur, ...
# 473543  Concussion with loss of consciousness greater ...
# 473544  Other specified injury of unspecified blood ve...
# 473545  Passenger on bus injured in collision with rai...
#
#                                                negative_9  \
# 0       Other fracture of left great toe, initial enco...
# 1       Puncture wound without foreign body of left ri...
# 2       Sprain of tarsometatarsal ligament of unspecif...
# 3       Contusion of right great toe with damage to na...
# 4       Breakdown (mechanical) of internal fixation de...
# ...                                                   ...
# 473541               Toxic effect of cobra venom, assault
# 473542  Displaced fracture of medial wall of unspecifi...
# 473543  Poisoning by other primarily systemic and hema...
# 473544  Fracture of radius or ulna following insertion...
# 473545  Displaced avulsion fracture of right ischium, ...
#
#                                               negative_10
# 0       Unspecified fracture of upper end of unspecifi...
# 1       Nondisplaced fracture of epiphysis (separation...
# 2       Burn of first degree of multiple sites of left...
# 3       Displaced oblique fracture of shaft of left fe...
# 4                          Maternal care for unstable lie
# ...                                                   ...
# 473541       Obstructive and reflux uropathy, unspecified
# 473542  Displaced fracture of lateral end of left clav...
# 473543     Paper entering through skin, initial encounter
# 473544  Other fracture of upper end of left tibia, sub...
# 473545  Poisoning by predominantly alpha-adrenorecepto...
#
# [473546 rows x 12 columns]
